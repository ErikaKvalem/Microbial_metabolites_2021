# %%
import scanpy as sc

# %%
import sccoda.util.cell_composition_data as scc_dat
import sccoda.util.data_visualization as scc_viz

# %%
adata = sc.read_h5ad("/data/projects/2021/MicrobialMetabolites/single-cell-sorted-cd8/results/results_by_sample/merge_and_solo_samples/adata_nodoublet.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 80145 × 13646
#     obs: 'sample_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'n_counts', 'n_genes', 'value', '_scvi_batch', '_scvi_labels', 'outlier', 'mt_outlier', 'is_doublet', 'leiden'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
adata.obs
# Out:
#                       sample_id  n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACCTGAGCCACGTC-0   11mix-ICI1               1264                 7.142827
# AAACCTGAGCTACCGC-0   11mix-ICI1               2487                 7.819234
# AAACCTGAGGAATGGA-0   11mix-ICI1               1366                 7.220374
# AAACCTGAGGGAGTAA-0   11mix-ICI1               2268                 7.727094
# AAACCTGAGGTACTCT-0   11mix-ICI1               2768                 7.926242
# ...                         ...                ...                      ...
# TTTGTCATCATCGGAT-12     GF-ICI2               2133                 7.665753
# TTTGTCATCGGCGCTA-12     GF-ICI2               1739                 7.461640
# TTTGTCATCGTATCAG-12     GF-ICI2               2227                 7.708860
# TTTGTCATCTCTAAGG-12     GF-ICI2               1304                 7.173958
# TTTGTCATCTGACCTC-12     GF-ICI2               3020                 8.013343
#
#                      total_counts  log1p_total_counts  \
# AAACCTGAGCCACGTC-0           5757            8.658345
# AAACCTGAGCTACCGC-0          12206            9.409765
# AAACCTGAGGAATGGA-0           4861            8.489205
# AAACCTGAGGGAGTAA-0          11040            9.309371
# AAACCTGAGGTACTCT-0          12842            9.460554
# ...                           ...                 ...
# TTTGTCATCATCGGAT-12         10788            9.286282
# TTTGTCATCGGCGCTA-12         10163            9.226607
# TTTGTCATCGTATCAG-12          9648            9.174610
# TTTGTCATCTCTAAGG-12          7060            8.862342
# TTTGTCATCTGACCTC-12         19441            9.875191
#
#                      pct_counts_in_top_20_genes  total_counts_mt  \
# AAACCTGAGCCACGTC-0                    58.693764               37
# AAACCTGAGCTACCGC-0                    44.912338              122
# AAACCTGAGGAATGGA-0                    51.018309               47
# AAACCTGAGGGAGTAA-0                    40.153986              134
# AAACCTGAGGTACTCT-0                    36.606448               84
# ...                                         ...              ...
# TTTGTCATCATCGGAT-12                   38.932147              158
# TTTGTCATCGGCGCTA-12                   58.958969              122
# TTTGTCATCGTATCAG-12                   30.234245              222
# TTTGTCATCTCTAAGG-12                   73.739377              179
# TTTGTCATCTGACCTC-12                   40.769508              342
#
#                      log1p_total_counts_mt  pct_counts_mt  total_counts_ribo  \
# AAACCTGAGCCACGTC-0                3.637586       0.642696                749
# AAACCTGAGCTACCGC-0                4.812184       0.999508               1406
# AAACCTGAGGAATGGA-0                3.871201       0.966879                527
# AAACCTGAGGGAGTAA-0                4.905275       1.213768               1950
# AAACCTGAGGTACTCT-0                4.442651       0.654104               2538
# ...                                    ...            ...                ...
# TTTGTCATCATCGGAT-12               5.068904       1.464590               3792
# TTTGTCATCGGCGCTA-12               4.812184       1.200433               1406
# TTTGTCATCGTATCAG-12               5.407172       2.300995               3288
# TTTGTCATCTCTAAGG-12               5.192957       2.535411                 67
# TTTGTCATCTGACCTC-12               5.837730       1.759169               5240
#
#                      ...  n_genes  value  _scvi_batch  _scvi_labels  outlier  \
# AAACCTGAGCCACGTC-0   ...     1264      0            0             0    False
# AAACCTGAGCTACCGC-0   ...     2487      0            0             0    False
# AAACCTGAGGAATGGA-0   ...     1366      0            0             0    False
# AAACCTGAGGGAGTAA-0   ...     2268      0            0             0    False
# AAACCTGAGGTACTCT-0   ...     2768      0            0             0    False
# ...                  ...      ...    ...          ...           ...      ...
# TTTGTCATCATCGGAT-12  ...     2133      0            0             0    False
# TTTGTCATCGGCGCTA-12  ...     1739      0            0             0    False
# TTTGTCATCGTATCAG-12  ...     2227      0            0             0    False
# TTTGTCATCTCTAAGG-12  ...     1304      0            0             0     True
# TTTGTCATCTGACCTC-12  ...     3020      0            0             0    False
#
#                      mt_outlier  is_doublet  leiden  group  condition
# AAACCTGAGCCACGTC-0        False     singlet       0  11mix        ICI
# AAACCTGAGCTACCGC-0        False     singlet       0  11mix        ICI
# AAACCTGAGGAATGGA-0        False     singlet       0  11mix        ICI
# AAACCTGAGGGAGTAA-0        False     singlet       0  11mix        ICI
# AAACCTGAGGTACTCT-0        False     singlet       0  11mix        ICI
# ...                         ...         ...     ...    ...        ...
# TTTGTCATCATCGGAT-12       False     singlet       1     GF     No ICI
# TTTGTCATCGGCGCTA-12       False     singlet       0     GF     No ICI
# TTTGTCATCGTATCAG-12       False     singlet       1     GF     No ICI
# TTTGTCATCTCTAAGG-12       False     singlet       2     GF     No ICI
# TTTGTCATCTGACCTC-12       False     singlet       0     GF     No ICI
#
# [80145 rows x 26 columns]

# %%
adata.var
# Out:
#                     query notfound        _id     _score entrezgene  \
# 0                     1Ab     True        NaN        NaN        NaN
# 1                     2Ab     True        NaN        NaN        NaN
# 2                     3Ab     True        NaN        NaN        NaN
# 3                     4Ab     True        NaN        NaN        NaN
# 4                   CD103     True        NaN        NaN        NaN
# ...                   ...      ...        ...        ...        ...
# 13641  ENSMUSG00000118506      NaN      73545  22.452286      73545
# 13642  ENSMUSG00000118537      NaN  113002583  22.452286  113002583
# 13643  ENSMUSG00000118560      NaN     233187  22.452286     233187
# 13644                ICOS     True        NaN        NaN        NaN
# 13645                 PD1     True        NaN        NaN        NaN
#
#                                             name   symbol    taxid  \
# 0                                            NaN      1Ab      NaN
# 1                                            NaN      2Ab      NaN
# 2                                            NaN      3Ab      NaN
# 3                                            NaN      4Ab      NaN
# 4                                            NaN    CD103      NaN
# ...                                          ...      ...      ...
# 13641  cilia and flagella associated protein 141  Cfap141  10090.0
# 13642                 shieldin complex subunit 3    Shld3  10090.0
# 13643          lens intrinsic membrane protein 2     Lim2  10090.0
# 13644                                        NaN     ICOS      NaN
# 13645                                        NaN      PD1      NaN
#
#        highly_variable  highly_variable_rank       means      variances  \
# 0                 True                 844.5  270.752754  416016.187317
# 1                 True                 982.5  430.162106  847941.205521
# 2                 True                 592.5  241.608741  372805.200872
# 3                 True                 799.5  346.173456  598695.241562
# 4                 True                  15.5   28.075766   13589.296317
# ...                ...                   ...         ...            ...
# 13641             True                1562.0    0.007152       0.007346
# 13642            False                   NaN    0.053187       0.056046
# 13643            False                2798.0    0.003976       0.004471
# 13644             True                 202.5  106.447390   40098.740910
# 13645             True                 888.0  113.007130   24004.059101
#
#        variances_norm  highly_variable_nbatches
# 0            0.463186                         4
# 1            0.320557                         2
# 2            0.459693                         4
# 3            0.344697                         2
# 4            7.624407                         8
# ...               ...                       ...
# 13641        0.937616                         1
# 13642        0.914527                         0
# 13643        0.627925                         6
# 13644        1.712713                         8
# 13645        1.090026                         8
#
# [13646 rows x 14 columns]

# %%
samples = {
    "10mix-ICI1": {"group": "10mix", "condition":"ICI","origin":"tumor"},
    "10mix-ICI2": {"group": "10mix","condition":"ICI","origin":"tumor"},
    "11mix-ICI1": {"group": "11mix","condition":"ICI","origin":"tumor"},
    "11mix-ICI2": {"group": "11mix","condition":"ICI","origin":"tumor"},
    "GF-ICI1": {"group": "GF","condition":"No ICI","origin":"tumor"},
    "GF-ICI2": {"group": "GF","condition":"No ICI","origin":"tumor"},
    "GF-ICI1-plus": {"group": "GF-plus","condition":"ICI","origin":"tumor"},
    "GF-ICI2-plus": {"group": "GF-plus","condition":"ICI","origin":"tumor"},
    "10mix1": {"group": "10mix", "condition":"naive","origin":"colon"},
    "10mix2": {"group": "10mix", "condition":"naive","origin":"colon"},
    "11mix1": {"group": "11mix", "condition":"naive","origin":"colon"},
    "11mix2": {"group": "11mix", "condition":"naive","origin":"colon"},
    "GF1": {"group": "GF", "condition":"naive","origin":"colon"},
    "GF2": {"group": "GF", "condition":"naive","origin":"colon"},
}

# %%
# Set global met'adata on `mdata.obs`

adata.obs["group"] = adata.obs["sample_id"].map(lambda x: samples[x]["group"])
adata.obs["condition"] = adata.obs["sample_id"].map(lambda x: samples[x]["condition"])

# %%
adata.obs["condition"] = adata.obs["sample_id"].map(lambda x: samples[x]["condition"])

# %%
adata.obs["origin"] = adata.obs["sample_id"].map(lambda x: samples[x]["origin"])

# %%
adata.var_names_make_unique()

# %%
set(adata.obs.condition)
# Out:
# {'ICI', 'No ICI', 'naive'}

# %%
adata.var
# Out:
#                     highly_variable  highly_variable_rank       means  \
# 1Ab                            True                 844.5  270.752754
# 2Ab                            True                 982.5  430.162106
# 3Ab                            True                 592.5  241.608741
# 4Ab                            True                 799.5  346.173456
# CD103                          True                  15.5   28.075766
# ...                             ...                   ...         ...
# ENSMUSG00000118506             True                1562.0    0.007152
# ENSMUSG00000118537            False                   NaN    0.053187
# ENSMUSG00000118560            False                2798.0    0.003976
# ICOS                           True                 202.5  106.447390
# PD1                            True                 888.0  113.007130
#
#                         variances  variances_norm  highly_variable_nbatches
# 1Ab                 416016.187317        0.463186                         4
# 2Ab                 847941.205521        0.320557                         2
# 3Ab                 372805.200872        0.459693                         4
# 4Ab                 598695.241562        0.344697                         2
# CD103                13589.296317        7.624407                         8
# ...                           ...             ...                       ...
# ENSMUSG00000118506       0.007346        0.937616                         1
# ENSMUSG00000118537       0.056046        0.914527                         0
# ENSMUSG00000118560       0.004471        0.627925                         6
# ICOS                 40098.740910        1.712713                         8
# PD1                  24004.059101        1.090026                         8
#
# [13646 rows x 6 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 80145 × 13646
#     obs: 'sample_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'n_counts', 'n_genes', 'value', '_scvi_batch', '_scvi_labels', 'outlier', 'mt_outlier', 'is_doublet', 'leiden', 'group', 'condition'
#     var: 'query', 'notfound', '_id', '_score', 'entrezgene', 'name', 'symbol', 'taxid', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
import mygene

# %%
mg = mygene.MyGeneInfo()
list_var = adata.var.index.unique()
ginfo = mg.querymany(list_var, scopes='ensembl.gene')
df = pd.DataFrame(ginfo)
df.drop_duplicates(subset='query', keep='last', inplace=True)
adata.var["query"] = adata.var.index
adata.var = df.merge(adata.var, on='query', how='left')
adata.var['symbol'] = adata.var.apply(lambda row: row['query'] if pd.isna(row['symbol']) else row['symbol'], axis=1)
# Out:
# 43 input query terms found no hit:	['1Ab', '2Ab', '3Ab', '4Ab', 'CD103', 'CD44', 'CD69', 'ENSMUSG00000000325', 'ENSMUSG00000024952', 'E
# /home/kvalem/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     [0, 1, 2, 3, 4]
#
#     Inferred to be: integer
#
#   value_idx = self._prep_dim_index(value.index, attr)

# %%
cl_annotation = {
    "0": "IFN T-cells",
    "1": "Naive T-cells",
    "2": "Exhausted T-cells",
    "3": "Naive T-cells",
    "4":"Senescent-like T-cells",
    "5":"Exhausted T-cells",
    "6":"Naive T-cells",
    "7":"Exhausted T-cells",
    "8":"IFN T-cells",
    "9":"Senescent-like T-cells",
    "10":"Exhausted T-cells",
    "11":"Undefined",
    "12":"Naive T-cells",
    "13":"Stress response T-cells",
}

# %%
sc.tl.leiden(adata, resolution=0.7, key_added="leiden")
# Out:
# IOStream.flush timed out

# %%
sc.pl.umap(adata, color=["leiden"])
# Out:
# /home/kvalem/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color=["Ifng","Gzmb"], gene_symbols="symbol")
# Out:
# /home/kvalem/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.obs["cell_type_anno"] = adata.obs.leiden.map(cl_annotation)

# %%
sc.pl.umap(adata, color=["cell_type_anno"])
# Out:
# /home/kvalem/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
set(adata.obs["cell_type_anno"])
# Out:
# {'Exhausted T-cells',
#  'IFN T-cells',
#  'Naive T-cells',
#  'Senescent-like T-cells',
#  'Stress response T-cells',
#  'Undefined'}

# %%
adata.obs
# Out:
#                       sample_id  n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACCTGAGCCACGTC-0   11mix-ICI1               1264                 7.142827
# AAACCTGAGCTACCGC-0   11mix-ICI1               2487                 7.819234
# AAACCTGAGGAATGGA-0   11mix-ICI1               1366                 7.220374
# AAACCTGAGGGAGTAA-0   11mix-ICI1               2268                 7.727094
# AAACCTGAGGTACTCT-0   11mix-ICI1               2768                 7.926242
# ...                         ...                ...                      ...
# TTTGTCATCATCGGAT-12     GF-ICI2               2133                 7.665753
# TTTGTCATCGGCGCTA-12     GF-ICI2               1739                 7.461640
# TTTGTCATCGTATCAG-12     GF-ICI2               2227                 7.708860
# TTTGTCATCTCTAAGG-12     GF-ICI2               1304                 7.173958
# TTTGTCATCTGACCTC-12     GF-ICI2               3020                 8.013343
#
#                      total_counts  log1p_total_counts  \
# AAACCTGAGCCACGTC-0           5757            8.658345
# AAACCTGAGCTACCGC-0          12206            9.409765
# AAACCTGAGGAATGGA-0           4861            8.489205
# AAACCTGAGGGAGTAA-0          11040            9.309371
# AAACCTGAGGTACTCT-0          12842            9.460554
# ...                           ...                 ...
# TTTGTCATCATCGGAT-12         10788            9.286282
# TTTGTCATCGGCGCTA-12         10163            9.226607
# TTTGTCATCGTATCAG-12          9648            9.174610
# TTTGTCATCTCTAAGG-12          7060            8.862342
# TTTGTCATCTGACCTC-12         19441            9.875191
#
#                      pct_counts_in_top_20_genes  total_counts_mt  \
# AAACCTGAGCCACGTC-0                    58.693764               37
# AAACCTGAGCTACCGC-0                    44.912338              122
# AAACCTGAGGAATGGA-0                    51.018309               47
# AAACCTGAGGGAGTAA-0                    40.153986              134
# AAACCTGAGGTACTCT-0                    36.606448               84
# ...                                         ...              ...
# TTTGTCATCATCGGAT-12                   38.932147              158
# TTTGTCATCGGCGCTA-12                   58.958969              122
# TTTGTCATCGTATCAG-12                   30.234245              222
# TTTGTCATCTCTAAGG-12                   73.739377              179
# TTTGTCATCTGACCTC-12                   40.769508              342
#
#                      log1p_total_counts_mt  pct_counts_mt  total_counts_ribo  \
# AAACCTGAGCCACGTC-0                3.637586       0.642696                749
# AAACCTGAGCTACCGC-0                4.812184       0.999508               1406
# AAACCTGAGGAATGGA-0                3.871201       0.966879                527
# AAACCTGAGGGAGTAA-0                4.905275       1.213768               1950
# AAACCTGAGGTACTCT-0                4.442651       0.654104               2538
# ...                                    ...            ...                ...
# TTTGTCATCATCGGAT-12               5.068904       1.464590               3792
# TTTGTCATCGGCGCTA-12               4.812184       1.200433               1406
# TTTGTCATCGTATCAG-12               5.407172       2.300995               3288
# TTTGTCATCTCTAAGG-12               5.192957       2.535411                 67
# TTTGTCATCTGACCTC-12               5.837730       1.759169               5240
#
#                      ...  value  _scvi_batch  _scvi_labels  outlier  \
# AAACCTGAGCCACGTC-0   ...      0            0             0    False
# AAACCTGAGCTACCGC-0   ...      0            0             0    False
# AAACCTGAGGAATGGA-0   ...      0            0             0    False
# AAACCTGAGGGAGTAA-0   ...      0            0             0    False
# AAACCTGAGGTACTCT-0   ...      0            0             0    False
# ...                  ...    ...          ...           ...      ...
# TTTGTCATCATCGGAT-12  ...      0            0             0    False
# TTTGTCATCGGCGCTA-12  ...      0            0             0    False
# TTTGTCATCGTATCAG-12  ...      0            0             0    False
# TTTGTCATCTCTAAGG-12  ...      0            0             0     True
# TTTGTCATCTGACCTC-12  ...      0            0             0    False
#
#                      mt_outlier  is_doublet  leiden  group  treatment  \
# AAACCTGAGCCACGTC-0        False     singlet       8  11mix        ICI
# AAACCTGAGCTACCGC-0        False     singlet       0  11mix        ICI
# AAACCTGAGGAATGGA-0        False     singlet       0  11mix        ICI
# AAACCTGAGGGAGTAA-0        False     singlet       9  11mix        ICI
# AAACCTGAGGTACTCT-0        False     singlet       0  11mix        ICI
# ...                         ...         ...     ...    ...        ...
# TTTGTCATCATCGGAT-12       False     singlet       6     GF     No ICI
# TTTGTCATCGGCGCTA-12       False     singlet       8     GF     No ICI
# TTTGTCATCGTATCAG-12       False     singlet       6     GF     No ICI
# TTTGTCATCTCTAAGG-12       False     singlet       5     GF     No ICI
# TTTGTCATCTGACCTC-12       False     singlet       8     GF     No ICI
#
#                              cell_type_anno
# AAACCTGAGCCACGTC-0              IFN T-cells
# AAACCTGAGCTACCGC-0              IFN T-cells
# AAACCTGAGGAATGGA-0              IFN T-cells
# AAACCTGAGGGAGTAA-0   Senescent-like T-cells
# AAACCTGAGGTACTCT-0              IFN T-cells
# ...                                     ...
# TTTGTCATCATCGGAT-12           Naive T-cells
# TTTGTCATCGGCGCTA-12             IFN T-cells
# TTTGTCATCGTATCAG-12           Naive T-cells
# TTTGTCATCTCTAAGG-12       Exhausted T-cells
# TTTGTCATCTGACCTC-12             IFN T-cells
#
# [80145 rows x 27 columns]

# %%
sc.pl.umap(adata, color=["origin"])
# Out:
# /home/kvalem/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 80145 × 13646
#     obs: 'sample_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'n_counts', 'n_genes', 'value', '_scvi_batch', '_scvi_labels', 'outlier', 'mt_outlier', 'is_doublet', 'leiden', 'group', 'treatment', 'cell_type_anno'
#     var: 'query', 'notfound', '_id', '_score', 'entrezgene', 'name', 'symbol', 'taxid', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap', 'cell_type_anno_colors', 'leiden_colors'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
adata_qc = sc.read_h5ad("mdata_qc.h5ad")

# %%
adata_qc
# Out:
# AnnData object with n_obs × n_vars = 14042 × 18327
#     obs: 'sample', 'group', 'condition', 'n_genes', 'n_counts', 'leiden', 'origin', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'outlier', 'cell_type_coarse'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'cell_type_coarse_colors', 'gex:group_colors', 'gex:leiden_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'origin_colors', 'pca', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### Compositional analysis

# %%
adata.obs.rename(columns={"condition":"treatment"}, inplace = True)

# %%
set(adata.obs.sample_id)
# Out:
# {'10mix-ICI1',
#  '10mix-ICI2',
#  '10mix1',
#  '10mix2',
#  '11mix-ICI1',
#  '11mix-ICI2',
#  '11mix1',
#  '11mix2',
#  'GF-ICI1',
#  'GF-ICI1-plus',
#  'GF-ICI2',
#  'GF-ICI2-plus',
#  'GF1'}

# %%
frac_by_condition = (
    adata.obs.groupby(["group","sample_id","treatment"])
    .apply(lambda x: x.value_counts("cell_type_anno", normalize=False))
    .reset_index(name="n_cells")
    .assign(condition=lambda x: x["group"].astype(str))
)

# %%
frac_by_condition = frac_by_condition[frac_by_condition['cell_type_anno'] != 'Undefined']

# %%
frac_by_condition = frac_by_condition[frac_by_condition['cell_type_anno'] != 'Stress response T-cells']

# %%
frac_by_condition = frac_by_condition[frac_by_condition['condition'] != 'GF-plus']

# %%
frac_by_condition = frac_by_condition[frac_by_condition['treatment'] != 'No ICI']

# %%
frac_by_condition = frac_by_condition[frac_by_condition['treatment'] != 'ICI']

# %%
frac_by_condition.group.replace("GF-plus","GF",inplace=True)

# %%
frac_by_condition.group.replace("No ICI	","naive",inplace=True)

# %%
for index, row in frac_by_condition.iterrows():
    if row["treatment"] == "naive":
        frac_by_condition.loc[index, "experiment"] = "2019"
    else:
        frac_by_condition.loc[index, "experiment"] = "2021"

# %%
set(frac_by_condition.condition)
# Out:
# {'10mix', '11mix', 'GF'}

# %%
frac_by_condition
# Out:
#     group     sample_id treatment          cell_type_anno  n_cells condition  \
# 0   10mix        10mix1     naive           Naive T-cells     2319     10mix
# 1   10mix        10mix1     naive       Exhausted T-cells      973     10mix
# 2   10mix        10mix1     naive  Senescent-like T-cells       87     10mix
# 3   10mix        10mix1     naive             IFN T-cells       45     10mix
# 6   10mix        10mix2     naive           Naive T-cells     1713     10mix
# 7   10mix        10mix2     naive       Exhausted T-cells      780     10mix
# 8   10mix        10mix2     naive  Senescent-like T-cells       53     10mix
# 9   10mix        10mix2     naive             IFN T-cells       40     10mix
# 12  10mix    10mix-ICI1       ICI       Exhausted T-cells     4162     10mix
# 13  10mix    10mix-ICI1       ICI             IFN T-cells     1909     10mix
# 14  10mix    10mix-ICI1       ICI  Senescent-like T-cells     1262     10mix
# 15  10mix    10mix-ICI1       ICI           Naive T-cells     1156     10mix
# 18  10mix    10mix-ICI2       ICI           Naive T-cells     3944     10mix
# 19  10mix    10mix-ICI2       ICI       Exhausted T-cells     2043     10mix
# 20  10mix    10mix-ICI2       ICI             IFN T-cells     1802     10mix
# 21  10mix    10mix-ICI2       ICI  Senescent-like T-cells     1150     10mix
# 24  11mix        11mix1     naive           Naive T-cells     1521     11mix
# 25  11mix        11mix1     naive       Exhausted T-cells     1435     11mix
# 26  11mix        11mix1     naive  Senescent-like T-cells      128     11mix
# 27  11mix        11mix1     naive             IFN T-cells       83     11mix
# 30  11mix        11mix2     naive           Naive T-cells     2071     11mix
# 31  11mix        11mix2     naive       Exhausted T-cells     1983     11mix
# 32  11mix        11mix2     naive  Senescent-like T-cells      144     11mix
# 33  11mix        11mix2     naive             IFN T-cells      130     11mix
# 36  11mix    11mix-ICI1       ICI             IFN T-cells     3560     11mix
# 37  11mix    11mix-ICI1       ICI       Exhausted T-cells     2893     11mix
# 38  11mix    11mix-ICI1       ICI  Senescent-like T-cells     1135     11mix
# 39  11mix    11mix-ICI1       ICI           Naive T-cells      910     11mix
# 42  11mix    11mix-ICI2       ICI             IFN T-cells     2995     11mix
# 43  11mix    11mix-ICI2       ICI           Naive T-cells     2359     11mix
# 44  11mix    11mix-ICI2       ICI       Exhausted T-cells     1539     11mix
# 45  11mix    11mix-ICI2       ICI  Senescent-like T-cells     1126     11mix
# 48     GF           GF1     naive           Naive T-cells     2829        GF
# 49     GF           GF1     naive       Exhausted T-cells      257        GF
# 50     GF           GF1     naive  Senescent-like T-cells       26        GF
# 51     GF           GF1     naive             IFN T-cells       18        GF
# 54     GF       GF-ICI1    No ICI       Exhausted T-cells     2657        GF
# 55     GF       GF-ICI1    No ICI             IFN T-cells     1896        GF
# 56     GF       GF-ICI1    No ICI           Naive T-cells     1295        GF
# 57     GF       GF-ICI1    No ICI  Senescent-like T-cells      998        GF
# 60     GF       GF-ICI2    No ICI           Naive T-cells     2207        GF
# 61     GF       GF-ICI2    No ICI             IFN T-cells     1514        GF
# 62     GF       GF-ICI2    No ICI  Senescent-like T-cells     1003        GF
# 63     GF       GF-ICI2    No ICI       Exhausted T-cells      830        GF
# 66     GF  GF-ICI1-plus       ICI             IFN T-cells     2651   GF-plus
# 67     GF  GF-ICI1-plus       ICI       Exhausted T-cells     1875   GF-plus
# 68     GF  GF-ICI1-plus       ICI  Senescent-like T-cells     1318   GF-plus
# 69     GF  GF-ICI1-plus       ICI           Naive T-cells      787   GF-plus
# 72     GF  GF-ICI2-plus       ICI             IFN T-cells     2962   GF-plus
# 73     GF  GF-ICI2-plus       ICI       Exhausted T-cells     2033   GF-plus
# 74     GF  GF-ICI2-plus       ICI  Senescent-like T-cells     1594   GF-plus
# 75     GF  GF-ICI2-plus       ICI           Naive T-cells     1299   GF-plus
#
#    experiment
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 6        2019
# 7        2019
# 8        2019
# 9        2019
# 12       2021
# 13       2021
# 14       2021
# 15       2021
# 18       2021
# 19       2021
# 20       2021
# 21       2021
# 24       2019
# 25       2019
# 26       2019
# 27       2019
# 30       2019
# 31       2019
# 32       2019
# 33       2019
# 36       2021
# 37       2021
# 38       2021
# 39       2021
# 42       2021
# 43       2021
# 44       2021
# 45       2021
# 48       2019
# 49       2019
# 50       2019
# 51       2019
# 54       2021
# 55       2021
# 56       2021
# 57       2021
# 60       2021
# 61       2021
# 62       2021
# 63       2021
# 66       2021
# 67       2021
# 68       2021
# 69       2021
# 72       2021
# 73       2021
# 74       2021
# 75       2021

# %%
frac_pivot = (
    frac_by_condition.pivot(
        index=["group", "treatment","sample_id","experiment"],
        columns="cell_type_anno",
        values="n_cells",
    )
    .reset_index()
    #.drop(columns="other")
)

# %%
data_all = scc_dat.from_pandas(
    frac_pivot, covariate_columns=["group", "treatment","sample_id","experiment"]
)
# Out:
# /home/kvalem/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/sccoda/util/cell_composition_data.py:294: FutureWarning: X.dtype being converted to np.float32 from int64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   return ad.AnnData(X=count_data.values,

# %%
import pandas as pd

# %%
data_all.obs["group"] = pd.Categorical(
    data_all.obs["group"], categories=['10mix', '11mix','GF']
)

# %%
data_all.obs["treatment"] = pd.Categorical(
    data_all.obs["treatment"], categories=['ICI', 'naive']
)

# %%
data_all._sanitize()

# %%
scc_viz.boxplots(data_all, feature_name="group", figsize=(12, 5), cmap = "inferno")

#plt.savefig( "figures/cell_proportion_tumor_and_normal_sex.png")
# Out:
# <Axes: xlabel='Cell type', ylabel='Proportion'>

# %%
scc_viz.boxplots(data_all, feature_name="treatment", figsize=(12, 5), cmap = "inferno")

#plt.savefig( "figures/cell_proportion_tumor_and_normal_sex.png")
# Out:
# <Axes: xlabel='Cell type', ylabel='Proportion'>

# %%
data_all_2019.obs
# Out:
# cell_type_anno  group treatment sample_id experiment
# 2               10mix     naive    10mix1       2019
# 3               10mix     naive    10mix2       2019
# 6               11mix     naive    11mix1       2019
# 7               11mix     naive    11mix2       2019
# 12                 GF     naive       GF1       2019

# %%
scc_viz.boxplots(data_all_2019, feature_name="sample_id", figsize=(12, 5), cmap = "inferno")

#plt.savefig( "figures/cell_proportion_tumor_and_normal_sex.png")
# Out:
# <Axes: xlabel='Cell type', ylabel='Proportion'>

# %%
Tnaive - Ltb","Sell","Lef1","Nosip
Tex - Cxcr6","Gzmb","Havcr2","Ctla4"
Tsen - Plcg2","Igkc","Klrk1","Slamf7"
Tifn "Isg15","Ifit3","Ifit1","Stat1"
# Out:
#   Cell In[241], line 1
#     Tnaive - Ltb","Sell","Lef1","Nosip
#                 ^
# SyntaxError: invalid syntax

# %%
data_all_2019 = data_all[data_all.obs["experiment"]=="2019"]

# %%
data_all_2021 = data_all[data_all.obs["experiment"]=="2021"]

# %%
scc_viz.stacked_barplot(data_all_2019, feature_name="group")
# Out:
# <Axes: title={'center': 'group'}, ylabel='Proportion'>

# %%
scc_viz.stacked_barplot(data_all_2021, feature_name="group")
# Out:
# <Axes: title={'center': 'group'}, ylabel='Proportion'>

# %%
scc_viz.stacked_barplot(data_all_2021, feature_name="sample_id")
# Out:
# <Axes: title={'center': 'sample_id'}, ylabel='Proportion'>

# %%
scc_viz.stacked_barplot(data_all_2019, feature_name="sample_id")
# Out:
# <Axes: title={'center': 'sample_id'}, ylabel='Proportion'>

# %%
scc_viz.stacked_barplot(data_all, feature_name="treatment")
# Out:
# <Axes: title={'center': 'treatment'}, ylabel='Proportion'>

# %%
scc_viz.stacked_barplot(data_all, feature_name="sample_id")
# Out:
# <Axes: title={'center': 'sample_id'}, ylabel='Proportion'>
