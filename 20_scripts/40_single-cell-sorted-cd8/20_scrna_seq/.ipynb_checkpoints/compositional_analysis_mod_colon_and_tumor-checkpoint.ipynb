# %%
# TUTORIAL

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import anndata as ad
import warnings

from sccoda.util import cell_composition_data as dat
from sccoda.util import data_visualization as viz

import sccoda.datasets as scd

warnings.filterwarnings("ignore")

# %%
# read data
adata = ad.read_h5ad("/data/projects/2021/MicrobialMetabolites/single-cell-sorted-cd8/results/adata_solo_integrated.h5ad")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 74491 × 12052
#     obs: 'COND', '_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'cell_type', 'condition', 'is_doublet', 'is_outlier', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_mito', 'is_outlier_top_20', 'leiden', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'log1p_total_counts_ribo', 'n_counts', 'n_genes', 'n_genes_by_counts', 'origin', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'sample_id', 'total_counts', 'total_counts_mt', 'total_counts_ribo', 'value'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'COND_colors', 'cell_type_colors', 'condition_colors', 'dendrogram_leiden', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'neighbors_uncorrected', 'origin_colors', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected', 'ora_estimate', 'ora_pvals'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
def update_columns(row):
   
    if row['sample_id'] == "10mix1":
        row['condition'] = "10mix"
    elif row['sample_id'] == "10mix2":
         row['condition'] = "10mix"
    elif row['sample_id'] == "11mix1":
         row['condition'] = "11mix"
    elif row['sample_id'] == "11mix2":
         row['condition'] = "11mix"
    elif row['sample_id'] == "GF1":
         row['condition'] = "GF"
    elif row['sample_id'] == "GF2":
         row['condition'] = "GF"
    elif row['sample_id'] == "GF-ICI2-plus":
         row['condition'] = "GF-plus"
    elif row['sample_id'] == "GF-ICI1-plus":
         row['condition'] = "GF-plus"
    elif row['sample_id'] == "GF-ICI2":
         row['condition'] = "GF"
    elif row['sample_id'] == "GF-ICI1":
         row['condition'] = "GF"
    elif row['sample_id'] == "10mix-ICI1":
         row['condition'] = "10mix"
    elif row['sample_id'] == "10mix-ICI2":
         row['condition'] = "10mix"
    elif row['sample_id'] == "11mix-ICI1":
         row['condition'] = "11mix"
    elif row['sample_id'] == "11mix-ICI2":
         row['condition'] = "11mix"
    
    
        
        
    return row

# Apply the function to each row in the DataFrame
adata.obs = adata.obs.apply(update_columns, axis=1)

# %%
#def from_scanpy
sample_identifier = "cell_type"
cell_type_identifier  = "condition"
groups = adata.obs.value_counts([sample_identifier, cell_type_identifier])
count_data = groups.unstack(level=cell_type_identifier)
count_data = count_data.fillna(0)
covariate_df = pd.DataFrame(index=count_data.index)
if set(covariate_df.index) != set(count_data.index):
    raise ValueError("anndata sample names and covariate_df index do not have the same elements!")
covs_ord = covariate_df.reindex(count_data.index)
covs_ord.index = covs_ord.index.astype(str)
var_dat = count_data.sum(axis=0).rename("n_cells").to_frame()
var_dat.index = var_dat.index.astype(str)
ad.AnnData(X=count_data.values,
                  var=var_dat,
                  obs=covs_ord)
# Out:
# AnnData object with n_obs × n_vars = 6 × 4
#     var: 'n_cells'

# %%
count_data.columns.name = None
count_data["cell_type"] = count_data.index
count_data = count_data.reset_index(drop=True)

# %%
count_data
# Out:
#    10mix  11mix    GF  GF-plus cell_type
# 0   8909   9969  4631     7128       Tex
# 1   1561   3631  1428     2485      Tisg
# 2   8685   6390  5472     1967        Tn
# 3    445    527   404      461       Trm
# 4   1674   1320  1839     1553      Tsen
# 5   2258    623   938      193      Tstr

# %%
custom_order = ["10mix1", "10mix2", "11mix1", "11mix2","GF1","GF2","10mix-ICI1", "10mix-ICI2", "11mix-ICI1", "11mix-ICI2","GF-ICI1","GF-ICI2","GF-ICI1-plus","GF-ICI2-plus"]

count_data['sample_id'] = count_data['sample_id'].astype(pd.CategoricalDtype(categories=custom_order, ordered=True))
ordered_df = count_data.sort_values(by='sample_id')

# %%
data_f = dat.from_pandas(count_data, covariate_columns=["cell_type"])

# %%
data_f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data_f
#
# NameError: name 'data_f' is not defined

# %%
# Stacked barplot for each sample

ax=viz.stacked_barplot(data_f, feature_name="cell_type")
ax.set_ylabel("Fraction of cells (%)")

# Convert y-axis ticks to percentages
ax.set_yticklabels(['{:.0f}%'.format(x) for x in ax.get_yticks()])

#ax.yaxis.set_label_coords(1.1, 0.5)  # Adjust the coordinates as needed



# Move the y-axis label to the right side
ax.yaxis.tick_right()  # Place ticks on the right side
ax.yaxis.set_label_position("right")  # Position y-axis label on the right side
ax.yaxis.labelpad = 15  #

# Remove the border of the outer legend square
ax.legend(loc='lower left', bbox_to_anchor=(1, 1), frameon=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')

plt.savefig('composition.pdf', bbox_inches='tight')
plt.savefig('composition.svg', bbox_inches='tight')
plt.savefig('composition.png', bbox_inches='tight', dpi=300)  # Adjust dpi as needed
plt.show()

# %%
#def from_scanpy
sample_identifier = "cell_type"
cell_type_identifier  = "origin"
groups = adata.obs.value_counts([sample_identifier, cell_type_identifier])
count_data = groups.unstack(level=cell_type_identifier)
count_data = count_data.fillna(0)
covariate_df = pd.DataFrame(index=count_data.index)
if set(covariate_df.index) != set(count_data.index):
    raise ValueError("anndata sample names and covariate_df index do not have the same elements!")
covs_ord = covariate_df.reindex(count_data.index)
covs_ord.index = covs_ord.index.astype(str)
var_dat = count_data.sum(axis=0).rename("n_cells").to_frame()
var_dat.index = var_dat.index.astype(str)
ad.AnnData(X=count_data.values,
                  var=var_dat,
                  obs=covs_ord)
# Out:
# AnnData object with n_obs × n_vars = 6 × 2
#     var: 'n_cells'

# %%
count_data.columns.name = None
count_data["cell_type"] = count_data.index
count_data = count_data.reset_index(drop=True)

# %%
count_data
# Out:
#    colon    til cell_type
# 0   4452  26185       Tex
# 1    659   8446      Tisg
# 2   9297  13217        Tn
# 3    107   1730       Trm
# 4    140   6246      Tsen
# 5   1342   2670      Tstr

# %%
data_f = dat.from_pandas(count_data, covariate_columns=["cell_type"])

# %%
import matplotlib.patches as mpatches

# %%
# Stacked barplot for each sample
custom_colors = ['blue', 'pink']
ax=viz.stacked_barplot(data_f, feature_name="cell_type")
ax.set_ylabel("Fraction of cells (%)")


# Convert y-axis ticks to percentages
ax.set_yticklabels(['{:.0f}%'.format(x) for x in ax.get_yticks()])

#ax.yaxis.set_label_coords(1.1, 0.5)  # Adjust the coordinates as needed





# Move the y-axis label to the right side
ax.yaxis.tick_right()  # Place ticks on the right side
ax.yaxis.set_label_position("right")  # Position y-axis label on the right side
ax.yaxis.labelpad = 15  #

# Remove the border of the outer legend square
ax.legend(loc='lower left', bbox_to_anchor=(1, 1), frameon=False)
ax.set_xticklabels([])
ax.set_xticklabels([])
colors = ['blue', 'pink']  # Adjust colors as needed

# Loop through each container in the plot and set the colors
for container, color in zip(ax.containers, colors):
    for patch in container.patches:
        patch.set_facecolor(color)
        
        # Create custom legend handles and labels
legend_handles = [mpatches.Patch(color=color, label=label) for color, label in zip(colors, ['Colon', 'TIL'])]

# Modify the legend using the custom handles and labels
ax.legend(handles=legend_handles, loc='upper left', bbox_to_anchor=(1, 1.5), frameon=False)


plt.savefig('composition_origin.pdf', bbox_inches='tight')
plt.savefig('composition_origin.svg', bbox_inches='tight')
plt.savefig('composition_origin.png', bbox_inches='tight', dpi=300)  # Adjust dpi as needed

plt.show()

# %%
adata.obs.origin.value_counts()
# Out:
# til      58494
# colon    15997
# Name: origin, dtype: int64

# %%
# Create a stacked barplot with rotated x-axis and switched axes
.pl.stacked_barplot(data_f, feature_name="sample_id", swap_axes=True, rotation=45)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Create a stacked barplot with rotated x-axis and switched axes
# ----> 2 viz.pl.stacked_barplot(data_f, feature_name="sample_id", swap_axes=True, rotation=45)
#       4 plt.show()
#
# AttributeError: module 'sccoda.util.data_visualization' has no attribute 'pl'

# %%
# Stacked barplot for each sample
viz.stacked_barplot(data_f, feature_name="origin")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Stacked barplot for each sample
# ----> 2 viz.stacked_barplot(data_f, feature_name="origin")
#       3 plt.show()
#
# File ~/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/sccoda/util/data_visualization.py:153, in stacked_barplot(data, feature_name, figsize, dpi, cmap, plot_legend, level_order)
#     151     assert set(level_order) == set(data.obs[feature_name]), "level order is inconsistent with levels"
#     152     levels = level_order
# --> 153 elif hasattr(data.obs[feature_name], 'cat'):
#     154     levels = data.obs[feature_name].cat.categories.to_list()
#     155 else:
#
# File ~/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'origin'

# %%
# Grouped boxplots. No facets, relative abundance, no dots.
viz.boxplots(
    data_f,
    feature_name="sex",
    plot_facets=False,
    y_scale="relative",
    add_dots=False,
)
plt.show()

# Grouped boxplots. Facets, log scale, added dots and custom color palette.
viz.boxplots(
    data_f,
    feature_name="sex",
    plot_facets=True,
    y_scale="log",
    add_dots=True,
    cmap="Reds",
)
plt.show()

# %%
viz.rel_abundance_dispersion_plot(
    data=data_f,
    abundant_threshold=0.9
)
plt.show()

# %%
from sccoda.util import comp_ana as mod
# Out:
# 2023-04-09 16:47:26.427610: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_salm = mod.CompositionalAnalysis(data_f, formula="sex", reference_cell_type="malignant cell")

# %%
# Run MCMC
sim_results = model_salm.sample_hmc()
# Out:
# WARNING:tensorflow:From /home/kvalem/.conda/envs/nsclc_gender_atlas_23/lib/python3.9/site-packages/tensorflow_probability/python/internal/batched_rejection_sampler.py:102: calling while_loop_v2 (from tensorflow.python.ops.control_flow_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.while_loop(c, b, vars, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.while_loop(c, b, vars))
# 100%|██████████| 20000/20000 [02:49<00:00, 117.92it/s]
# MCMC sampling finished. (214.727 sec)
# Acceptance rate: 38.9%

# %%
sim_results.summary()
# Out:
# Compositional Analysis summary:
#
# Data: 2 samples, 33 cell types
# Reference index: 22
# Formula: sex
#
# Intercepts:
#                                       Final Parameter  Expected Sample
# Cell Type
# mesothelial cell                                0.631       150.728797
# epithelial cell of lung                         2.474       951.921121
# mast cell                                       3.395      2391.036363
# club cell                                       1.437       337.471876
# smooth muscle cell                              1.550       377.844288
# macrophage                                      4.662      8488.623850
# B cell                                          3.193      1953.703684
# dendritic cell                                  0.986       214.966494
# stromal cell                                   -1.631        15.697197
# alveolar macrophage                             6.012     32744.234359
# natural killer cell                             5.303     16114.619388
# CD4-positive, alpha-beta T cell                 5.911     29598.595074
# CD8-positive, alpha-beta T cell                 5.533     20281.860122
# pericyte                                        0.268       104.844906
# myeloid cell                                    2.327       821.787771
# neutrophil                                      3.751      3413.461559
# plasmacytoid dendritic cell                     2.024       606.971705
# plasma cell                                     2.632      1114.857837
# regulatory T cell                               3.180      1928.469911
# classical monocyte                              4.874     10493.194419
# non-classical monocyte                          3.286      2144.115036
# conventional dendritic cell                     1.711       443.848006
# malignant cell                                  1.479       351.947556
# type I pneumocyte                               2.808      1329.398915
# type II pneumocyte                              3.975      4270.482833
# endothelial cell of lymphatic vessel            2.344       835.877587
# capillary endothelial cell                      3.801      3588.473476
# CD1c-positive myeloid dendritic cell            3.552      2797.502057
# vein endothelial cell                           3.309      2194.001173
# fibroblast of lung                              2.449       928.418105
# multi-ciliated epithelial cell                  3.005      1618.867606
# pulmonary artery endothelial cell               2.178       708.026962
# bronchus fibroblast of lung                    -0.141        69.649963
#
#
# Effects:
#                                                   Final Parameter  \
# Covariate   Cell Type
# sex[T.male] mesothelial cell                             0.000000
#             epithelial cell of lung                      0.000000
#             mast cell                                    0.000000
#             club cell                                    0.000000
#             smooth muscle cell                           0.000000
#             macrophage                                   0.000000
#             B cell                                       0.000000
#             dendritic cell                               0.000000
#             stromal cell                                 0.000000
#             alveolar macrophage                         -0.300379
#             natural killer cell                          0.000000
#             CD4-positive, alpha-beta T cell              0.000000
#             CD8-positive, alpha-beta T cell              0.000000
#             pericyte                                     0.000000
#             myeloid cell                                 0.000000
#             neutrophil                                   0.000000
#             plasmacytoid dendritic cell                  0.000000
#             plasma cell                                  0.000000
#             regulatory T cell                            0.000000
#             classical monocyte                           0.000000
#             non-classical monocyte                       0.000000
#             conventional dendritic cell                  0.000000
#             malignant cell                               0.000000
#             type I pneumocyte                            0.000000
#             type II pneumocyte                           0.000000
#             endothelial cell of lymphatic vessel         0.000000
#             capillary endothelial cell                   0.000000
#             CD1c-positive myeloid dendritic cell         0.000000
#             vein endothelial cell                        0.000000
#             fibroblast of lung                           0.000000
#             multi-ciliated epithelial cell               0.000000
#             pulmonary artery endothelial cell            0.000000
#             bronchus fibroblast of lung                  0.000000
#
#                                                   Expected Sample  \
# Covariate   Cell Type
# sex[T.male] mesothelial cell                           159.567099
#             epithelial cell of lung                   1007.739029
#             mast cell                                 2531.239836
#             club cell                                  357.260253
#             smooth muscle cell                         399.999987
#             macrophage                                8986.372259
#             B cell                                    2068.263231
#             dendritic cell                             227.571509
#             stromal cell                                16.617636
#             alveolar macrophage                      25670.178651
#             natural killer cell                      17059.534170
#             CD4-positive, alpha-beta T cell          31334.171283
#             CD8-positive, alpha-beta T cell          21471.129876
#             pericyte                                   110.992709
#             myeloid cell                               869.975035
#             neutrophil                                3613.617096
#             plasmacytoid dendritic cell                642.562774
#             plasma cell                               1180.229884
#             regulatory T cell                         2041.549822
#             classical monocyte                       11108.485062
#             non-classical monocyte                    2269.839755
#             conventional dendritic cell                469.873973
#             malignant cell                             372.584745
#             type I pneumocyte                         1407.351031
#             type II pneumocyte                        4520.891624
#             endothelial cell of lymphatic vessel       884.891037
#             capillary endothelial cell                3798.891206
#             CD1c-positive myeloid dendritic cell      2961.539505
#             vein endothelial cell                     2322.651071
#             fibroblast of lung                         982.857864
#             multi-ciliated epithelial cell            1713.793332
#             pulmonary artery endothelial cell          749.543620
#             bronchus fibroblast of lung                 73.734036
#
#                                                   log2-fold change
# Covariate   Cell Type
# sex[T.male] mesothelial cell                              0.082208
#             epithelial cell of lung                       0.082208
#             mast cell                                     0.082208
#             club cell                                     0.082208
#             smooth muscle cell                            0.082208
#             macrophage                                    0.082208
#             B cell                                        0.082208
#             dendritic cell                                0.082208
#             stromal cell                                  0.082208
#             alveolar macrophage                          -0.351148
#             natural killer cell                           0.082208
#             CD4-positive, alpha-beta T cell               0.082208
#             CD8-positive, alpha-beta T cell               0.082208
#             pericyte                                      0.082208
#             myeloid cell                                  0.082208
#             neutrophil                                    0.082208
#             plasmacytoid dendritic cell                   0.082208
#             plasma cell                                   0.082208
#             regulatory T cell                             0.082208
#             classical monocyte                            0.082208
#             non-classical monocyte                        0.082208
#             conventional dendritic cell                   0.082208
#             malignant cell                                0.082208
#             type I pneumocyte                             0.082208
#             type II pneumocyte                            0.082208
#             endothelial cell of lymphatic vessel          0.082208
#             capillary endothelial cell                    0.082208
#             CD1c-positive myeloid dendritic cell          0.082208
#             vein endothelial cell                         0.082208
#             fibroblast of lung                            0.082208
#             multi-ciliated epithelial cell                0.082208
#             pulmonary artery endothelial cell             0.082208
#             bronchus fibroblast of lung                   0.082208

# %%
print(sim_results.credible_effects())
# Out:
# Covariate    Cell Type
# sex[T.male]  mesothelial cell                        False
#              epithelial cell of lung                 False
#              mast cell                               False
#              club cell                               False
#              smooth muscle cell                      False
#              macrophage                              False
#              B cell                                  False
#              dendritic cell                          False
#              stromal cell                            False
#              alveolar macrophage                      True
#              natural killer cell                     False
#              CD4-positive, alpha-beta T cell         False
#              CD8-positive, alpha-beta T cell         False
#              pericyte                                False
#              myeloid cell                            False
#              neutrophil                              False
#              plasmacytoid dendritic cell             False
#              plasma cell                             False
#              regulatory T cell                       False
#              classical monocyte                      False
#              non-classical monocyte                  False
#              conventional dendritic cell             False
#              malignant cell                          False
#              type I pneumocyte                       False
#              type II pneumocyte                      False
#              endothelial cell of lymphatic vessel    False
#              capillary endothelial cell              False
#              CD1c-positive myeloid dendritic cell    False
#              vein endothelial cell                   False
#              fibroblast of lung                      False
#              multi-ciliated epithelial cell          False
#              pulmonary artery endothelial cell       False
#              bronchus fibroblast of lung             False
# Name: Final Parameter, dtype: bool

# %%
sim_results.set_fdr(est_fdr=0.05)
sim_results.summary()
# Out:
# Compositional Analysis summary:
#
# Data: 2 samples, 33 cell types
# Reference index: 22
# Formula: sex
#
# Intercepts:
#                                       Final Parameter  Expected Sample
# Cell Type
# mesothelial cell                                0.631       150.728797
# epithelial cell of lung                         2.474       951.921121
# mast cell                                       3.395      2391.036363
# club cell                                       1.437       337.471876
# smooth muscle cell                              1.550       377.844288
# macrophage                                      4.662      8488.623850
# B cell                                          3.193      1953.703684
# dendritic cell                                  0.986       214.966494
# stromal cell                                   -1.631        15.697197
# alveolar macrophage                             6.012     32744.234359
# natural killer cell                             5.303     16114.619388
# CD4-positive, alpha-beta T cell                 5.911     29598.595074
# CD8-positive, alpha-beta T cell                 5.533     20281.860122
# pericyte                                        0.268       104.844906
# myeloid cell                                    2.327       821.787771
# neutrophil                                      3.751      3413.461559
# plasmacytoid dendritic cell                     2.024       606.971705
# plasma cell                                     2.632      1114.857837
# regulatory T cell                               3.180      1928.469911
# classical monocyte                              4.874     10493.194419
# non-classical monocyte                          3.286      2144.115036
# conventional dendritic cell                     1.711       443.848006
# malignant cell                                  1.479       351.947556
# type I pneumocyte                               2.808      1329.398915
# type II pneumocyte                              3.975      4270.482833
# endothelial cell of lymphatic vessel            2.344       835.877587
# capillary endothelial cell                      3.801      3588.473476
# CD1c-positive myeloid dendritic cell            3.552      2797.502057
# vein endothelial cell                           3.309      2194.001173
# fibroblast of lung                              2.449       928.418105
# multi-ciliated epithelial cell                  3.005      1618.867606
# pulmonary artery endothelial cell               2.178       708.026962
# bronchus fibroblast of lung                    -0.141        69.649963
#
#
# Effects:
#                                                   Final Parameter  \
# Covariate   Cell Type
# sex[T.male] mesothelial cell                             0.000000
#             epithelial cell of lung                      0.000000
#             mast cell                                    0.000000
#             club cell                                    0.000000
#             smooth muscle cell                           0.000000
#             macrophage                                   0.000000
#             B cell                                       0.000000
#             dendritic cell                               0.000000
#             stromal cell                                 0.000000
#             alveolar macrophage                         -0.300379
#             natural killer cell                          0.000000
#             CD4-positive, alpha-beta T cell              0.000000
#             CD8-positive, alpha-beta T cell              0.000000
#             pericyte                                     0.000000
#             myeloid cell                                 0.000000
#             neutrophil                                   0.000000
#             plasmacytoid dendritic cell                  0.000000
#             plasma cell                                  0.000000
#             regulatory T cell                            0.000000
#             classical monocyte                           0.000000
#             non-classical monocyte                       0.000000
#             conventional dendritic cell                  0.000000
#             malignant cell                               0.000000
#             type I pneumocyte                            0.000000
#             type II pneumocyte                           0.000000
#             endothelial cell of lymphatic vessel         0.000000
#             capillary endothelial cell                   0.000000
#             CD1c-positive myeloid dendritic cell         0.000000
#             vein endothelial cell                        0.000000
#             fibroblast of lung                           0.000000
#             multi-ciliated epithelial cell               0.000000
#             pulmonary artery endothelial cell            0.000000
#             bronchus fibroblast of lung                  0.000000
#
#                                                   Expected Sample  \
# Covariate   Cell Type
# sex[T.male] mesothelial cell                           159.567099
#             epithelial cell of lung                   1007.739029
#             mast cell                                 2531.239836
#             club cell                                  357.260253
#             smooth muscle cell                         399.999987
#             macrophage                                8986.372259
#             B cell                                    2068.263231
#             dendritic cell                             227.571509
#             stromal cell                                16.617636
#             alveolar macrophage                      25670.178651
#             natural killer cell                      17059.534170
#             CD4-positive, alpha-beta T cell          31334.171283
#             CD8-positive, alpha-beta T cell          21471.129876
#             pericyte                                   110.992709
#             myeloid cell                               869.975035
#             neutrophil                                3613.617096
#             plasmacytoid dendritic cell                642.562774
#             plasma cell                               1180.229884
#             regulatory T cell                         2041.549822
#             classical monocyte                       11108.485062
#             non-classical monocyte                    2269.839755
#             conventional dendritic cell                469.873973
#             malignant cell                             372.584745
#             type I pneumocyte                         1407.351031
#             type II pneumocyte                        4520.891624
#             endothelial cell of lymphatic vessel       884.891037
#             capillary endothelial cell                3798.891206
#             CD1c-positive myeloid dendritic cell      2961.539505
#             vein endothelial cell                     2322.651071
#             fibroblast of lung                         982.857864
#             multi-ciliated epithelial cell            1713.793332
#             pulmonary artery endothelial cell          749.543620
#             bronchus fibroblast of lung                 73.734036
#
#                                                   log2-fold change
# Covariate   Cell Type
# sex[T.male] mesothelial cell                              0.082208
#             epithelial cell of lung                       0.082208
#             mast cell                                     0.082208
#             club cell                                     0.082208
#             smooth muscle cell                            0.082208
#             macrophage                                    0.082208
#             B cell                                        0.082208
#             dendritic cell                                0.082208
#             stromal cell                                  0.082208
#             alveolar macrophage                          -0.351148
#             natural killer cell                           0.082208
#             CD4-positive, alpha-beta T cell               0.082208
#             CD8-positive, alpha-beta T cell               0.082208
#             pericyte                                      0.082208
#             myeloid cell                                  0.082208
#             neutrophil                                    0.082208
#             plasmacytoid dendritic cell                   0.082208
#             plasma cell                                   0.082208
#             regulatory T cell                             0.082208
#             classical monocyte                            0.082208
#             non-classical monocyte                        0.082208
#             conventional dendritic cell                   0.082208
#             malignant cell                                0.082208
#             type I pneumocyte                             0.082208
#             type II pneumocyte                            0.082208
#             endothelial cell of lymphatic vessel          0.082208
#             capillary endothelial cell                    0.082208
#             CD1c-positive myeloid dendritic cell          0.082208
#             vein endothelial cell                         0.082208
#             fibroblast of lung                            0.082208
#             multi-ciliated epithelial cell                0.082208
#             pulmonary artery endothelial cell             0.082208
#             bronchus fibroblast of lung                   0.082208

# %%
print(sim_results.credible_effects())
# Out:
# Covariate    Cell Type
# sex[T.male]  mesothelial cell                        False
#              epithelial cell of lung                 False
#              mast cell                               False
#              club cell                               False
#              smooth muscle cell                      False
#              macrophage                              False
#              B cell                                  False
#              dendritic cell                          False
#              stromal cell                            False
#              alveolar macrophage                      True
#              natural killer cell                     False
#              CD4-positive, alpha-beta T cell         False
#              CD8-positive, alpha-beta T cell         False
#              pericyte                                False
#              myeloid cell                            False
#              neutrophil                              False
#              plasmacytoid dendritic cell             False
#              plasma cell                             False
#              regulatory T cell                       False
#              classical monocyte                      False
#              non-classical monocyte                  False
#              conventional dendritic cell             False
#              malignant cell                          False
#              type I pneumocyte                       False
#              type II pneumocyte                      False
#              endothelial cell of lymphatic vessel    False
#              capillary endothelial cell              False
#              CD1c-positive myeloid dendritic cell    False
#              vein endothelial cell                   False
#              fibroblast of lung                      False
#              multi-ciliated epithelial cell          False
#              pulmonary artery endothelial cell       False
#              bronchus fibroblast of lung             False
# Name: Final Parameter, dtype: bool

# %%
# Run scCODA with each cell type as the reference
cell_types = data_f.var.index
results_cycle = pd.DataFrame(index=cell_types, columns=["times_credible"]).fillna(0)

for ct in cell_types:
    print(f"Reference: {ct}")

    # Run inference
    model_temp = mod.CompositionalAnalysis(data_f, formula="sex",reference_cell_type=ct)
    temp_results = model_temp.sample_hmc(num_results=20000)

    # Select credible effects
    cred_eff = temp_results.credible_effects()
    cred_eff.index = cred_eff.index.droplevel(level=0)

    # add up credible effects
    results_cycle["times_credible"] += cred_eff.astype("int")
# Out:
# Reference: mesothelial cell
# 100%|██████████| 20000/20000 [02:47<00:00, 119.08it/s]
# MCMC sampling finished. (213.086 sec)
# Acceptance rate: 63.7%
# Reference: epithelial cell of lung
# 100%|██████████| 20000/20000 [02:44<00:00, 121.52it/s]
# MCMC sampling finished. (206.140 sec)
# Acceptance rate: 32.1%
# Reference: mast cell
# 100%|██████████| 20000/20000 [02:45<00:00, 120.51it/s]
# MCMC sampling finished. (212.748 sec)
# Acceptance rate: 55.5%
# Reference: club cell
# 100%|██████████| 20000/20000 [02:38<00:00, 126.55it/s]
# WARNING:tensorflow:5 out of the last 5 calls to <function CompositionalModel.sampling.<locals>.sample_mcmc at 0x7f5f5c376af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MCMC sampling finished. (200.279 sec)
# Acceptance rate: 6.7%
# Reference: smooth muscle cell
# 100%|██████████| 20000/20000 [02:45<00:00, 120.97it/s]
# WARNING:tensorflow:6 out of the last 6 calls to <function CompositionalModel.sampling.<locals>.sample_mcmc at 0x7f5f5c376af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MCMC sampling finished. (210.221 sec)
# Acceptance rate: 43.2%
# Reference: macrophage
# 100%|██████████| 20000/20000 [02:39<00:00, 125.17it/s]
# MCMC sampling finished. (202.477 sec)
# Acceptance rate: 5.7%
# Reference: B cell
# 100%|██████████| 20000/20000 [02:45<00:00, 120.49it/s]
# MCMC sampling finished. (207.829 sec)
# Acceptance rate: 26.2%
# Reference: dendritic cell
# 100%|██████████| 20000/20000 [02:45<00:00, 120.62it/s]
# MCMC sampling finished. (211.239 sec)
# Acceptance rate: 28.1%
# Reference: stromal cell
# 100%|██████████| 20000/20000 [02:47<00:00, 119.33it/s]
# MCMC sampling finished. (213.094 sec)
# Acceptance rate: 60.5%
# Reference: alveolar macrophage
# 100%|██████████| 20000/20000 [02:47<00:00, 119.34it/s]
# MCMC sampling finished. (213.952 sec)
# Acceptance rate: 59.5%
# Reference: natural killer cell
# 100%|██████████| 20000/20000 [03:04<00:00, 108.61it/s]
# MCMC sampling finished. (235.614 sec)
# Acceptance rate: 59.1%
# Reference: CD4-positive, alpha-beta T cell
# 100%|██████████| 20000/20000 [03:07<00:00, 106.90it/s]
# MCMC sampling finished. (237.554 sec)
# Acceptance rate: 74.4%
# Reference: CD8-positive, alpha-beta T cell
# 100%|██████████| 20000/20000 [03:08<00:00, 106.18it/s]
# MCMC sampling finished. (239.270 sec)
# Acceptance rate: 53.3%
# Reference: pericyte
# 100%|██████████| 20000/20000 [03:07<00:00, 106.88it/s]
# MCMC sampling finished. (236.017 sec)
# Acceptance rate: 5.1%
# Reference: myeloid cell
# 100%|██████████| 20000/20000 [03:09<00:00, 105.44it/s]
# MCMC sampling finished. (241.185 sec)
# Acceptance rate: 51.0%
# Reference: neutrophil
# 100%|██████████| 20000/20000 [03:08<00:00, 106.19it/s]
# MCMC sampling finished. (238.902 sec)
# Acceptance rate: 77.2%
# Reference: plasmacytoid dendritic cell
# 100%|██████████| 20000/20000 [03:03<00:00, 108.83it/s]
# MCMC sampling finished. (231.909 sec)
# Acceptance rate: 8.9%
# Reference: plasma cell
# 100%|██████████| 20000/20000 [03:00<00:00, 110.52it/s]
# MCMC sampling finished. (229.463 sec)
# Acceptance rate: 5.2%
# Reference: regulatory T cell
# 100%|██████████| 20000/20000 [03:08<00:00, 106.07it/s]
# MCMC sampling finished. (239.178 sec)
# Acceptance rate: 65.9%
# Reference: classical monocyte
# 100%|██████████| 20000/20000 [03:09<00:00, 105.38it/s]
# MCMC sampling finished. (242.015 sec)
# Acceptance rate: 43.8%
# Reference: non-classical monocyte
# 100%|██████████| 20000/20000 [03:12<00:00, 104.07it/s]
# MCMC sampling finished. (242.786 sec)
# Acceptance rate: 77.9%
# Reference: conventional dendritic cell
# 100%|██████████| 20000/20000 [03:09<00:00, 105.61it/s]
# MCMC sampling finished. (240.908 sec)
# Acceptance rate: 69.1%
# Reference: malignant cell
# 100%|██████████| 20000/20000 [03:02<00:00, 109.45it/s]
# MCMC sampling finished. (230.121 sec)
# Acceptance rate: 5.1%
# Reference: type I pneumocyte
# 100%|██████████| 20000/20000 [03:13<00:00, 103.36it/s]
# MCMC sampling finished. (244.231 sec)
# Acceptance rate: 56.2%
# Reference: type II pneumocyte
# 100%|██████████| 20000/20000 [03:09<00:00, 105.27it/s]
# MCMC sampling finished. (240.314 sec)
# Acceptance rate: 62.0%
# Reference: endothelial cell of lymphatic vessel
# 100%|██████████| 20000/20000 [03:09<00:00, 105.40it/s]
# MCMC sampling finished. (241.510 sec)
# Acceptance rate: 80.6%
# Reference: capillary endothelial cell
# 100%|██████████| 20000/20000 [03:10<00:00, 105.16it/s]
# MCMC sampling finished. (242.610 sec)
# Acceptance rate: 56.3%
# Reference: CD1c-positive myeloid dendritic cell
# 100%|██████████| 20000/20000 [03:13<00:00, 103.42it/s]
# MCMC sampling finished. (245.503 sec)
# Acceptance rate: 78.7%
# Reference: vein endothelial cell
# 100%|██████████| 20000/20000 [03:03<00:00, 108.91it/s]
# MCMC sampling finished. (229.373 sec)
# Acceptance rate: 55.8%
# Reference: fibroblast of lung
# 100%|██████████| 20000/20000 [02:44<00:00, 121.22it/s]
# MCMC sampling finished. (209.726 sec)
# Acceptance rate: 73.3%
# Reference: multi-ciliated epithelial cell
# 100%|██████████| 20000/20000 [02:46<00:00, 120.22it/s]
# MCMC sampling finished. (216.849 sec)
# Acceptance rate: 70.6%
# Reference: pulmonary artery endothelial cell
# 100%|██████████| 20000/20000 [03:10<00:00, 104.84it/s]
# MCMC sampling finished. (241.821 sec)
# Acceptance rate: 59.1%
# Reference: bronchus fibroblast of lung
# 100%|██████████| 20000/20000 [03:02<00:00, 109.35it/s]
# MCMC sampling finished. (230.643 sec)
# Acceptance rate: 11.3%

# %%
# Calculate percentages
results_cycle["pct_credible"] = results_cycle["times_credible"]/len(cell_types)
results_cycle["is_credible"] = results_cycle["pct_credible"] > 0.5
print(results_cycle)
# Out:
#                                       times_credible  pct_credible  \
# mesothelial cell                                   4      0.121212
# epithelial cell of lung                            4      0.121212
# mast cell                                          4      0.121212
# club cell                                          5      0.151515
# smooth muscle cell                                 5      0.151515
# macrophage                                         5      0.151515
# B cell                                             3      0.090909
# dendritic cell                                     2      0.060606
# stromal cell                                       2      0.060606
# alveolar macrophage                               28      0.848485
# natural killer cell                                4      0.121212
# CD4-positive, alpha-beta T cell                    3      0.090909
# CD8-positive, alpha-beta T cell                    4      0.121212
# pericyte                                           4      0.121212
# myeloid cell                                       4      0.121212
# neutrophil                                         8      0.242424
# plasmacytoid dendritic cell                        4      0.121212
# plasma cell                                        5      0.151515
# regulatory T cell                                  3      0.090909
# classical monocyte                                 3      0.090909
# non-classical monocyte                             1      0.030303
# conventional dendritic cell                        4      0.121212
# malignant cell                                     2      0.060606
# type I pneumocyte                                  2      0.060606
# type II pneumocyte                                 3      0.090909
# endothelial cell of lymphatic vessel               5      0.151515
# capillary endothelial cell                         6      0.181818
# CD1c-positive myeloid dendritic cell               4      0.121212
# vein endothelial cell                              2      0.060606
# fibroblast of lung                                 3      0.090909
# multi-ciliated epithelial cell                     3      0.090909
# pulmonary artery endothelial cell                  3      0.090909
# bronchus fibroblast of lung                        4      0.121212
#
#                                       is_credible
# mesothelial cell                            False
# epithelial cell of lung                     False
# mast cell                                   False
# club cell                                   False
# smooth muscle cell                          False
# macrophage                                  False
# B cell                                      False
# dendritic cell                              False
# stromal cell                                False
# alveolar macrophage                          True
# natural killer cell                         False
# CD4-positive, alpha-beta T cell             False
# CD8-positive, alpha-beta T cell             False
# pericyte                                    False
# myeloid cell                                False
# neutrophil                                  False
# plasmacytoid dendritic cell                 False
# plasma cell                                 False
# regulatory T cell                           False
# classical monocyte                          False
# non-classical monocyte                      False
# conventional dendritic cell                 False
# malignant cell                              False
# type I pneumocyte                           False
# type II pneumocyte                          False
# endothelial cell of lymphatic vessel        False
# capillary endothelial cell                  False
# CD1c-positive myeloid dendritic cell        False
# vein endothelial cell                       False
# fibroblast of lung                          False
# multi-ciliated epithelial cell              False
# pulmonary artery endothelial cell           False
# bronchus fibroblast of lung                 False
