# %% [markdown]
# # Unintegrated data

# %%
# Python packages
import scanpy as sc
import scvi
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
######################################################

# %%
path = "/data/projects/2021/MicrobialMetabolites/single-cell-sorted-cd8/results/solo_2021"

# %%
adata_solo = sc.read_h5ad(f"{path}/adata_nodoublet.h5ad")

# %%
adata_solo
# Out:
# AnnData object with n_obs × n_vars = 64345 × 10801
#     obs: 'sample_id', 'batch', 'n_counts', 'n_genes', 'value', '_scvi_batch', '_scvi_labels', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_top_20', 'is_outlier_mito', 'is_outlier', 'is_doublet', 'leiden'
#     var: 'ensembl_id_x', 'feature_types_x', 'gene_names', 'ensembl_id_y', 'feature_types_y', 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
adata_solo.obs.sample_id.value_counts()
# Out:
# sample_id
# 10mix-ICI1      9842
# 11mix-ICI1      9215
# 10mix-ICI2      8791
# GF-ICI2-plus    8508
# 11mix-ICI2      8355
# GF-ICI1         7411
# GF-ICI1-plus    7145
# GF-ICI2         5078
# Name: count, dtype: int64

# %%
adata_solo
# Out:
# AnnData object with n_obs × n_vars = 64345 × 10801
#     obs: 'sample_id', 'batch', 'n_counts', 'n_genes', 'value', '_scvi_batch', '_scvi_labels', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_top_20', 'is_outlier_mito', 'is_outlier', 'is_doublet', 'leiden'
#     var: 'ensembl_id_x', 'feature_types_x', 'gene_names', 'ensembl_id_y', 'feature_types_y', 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
adata_solo
# Out:
# AnnData object with n_obs × n_vars = 64345 × 10801
#     obs: 'sample_id', 'batch', 'n_counts', 'n_genes', 'value', '_scvi_batch', '_scvi_labels', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_top_20', 'is_outlier_mito', 'is_outlier', 'is_doublet', 'leiden'
#     var: 'ensembl_id_x', 'feature_types_x', 'gene_names', 'ensembl_id_y', 'feature_types_y', 'gene_name', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
sc.pl.umap(adata_solo, color=["leiden"], wspace=1)
# Out:
# /home/kvalem/.conda/envs/single_cell_sorted_scvi_2023/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata_solo[adata_solo.obs["batch_id"].isin(["ICI2"])].obs["sample_id"].value_counts()
# Out:
# sample_id
# 10mix-ICI2      8791
# GF-ICI2-plus    8508
# 11mix-ICI2      8355
# GF-ICI2         5078
# Name: count, dtype: int64

# %%
adata_solo[adata_solo.obs["batch_id"].isin(["ICI1"])].obs["sample_id"].value_counts()
# Out:
# sample_id
# 10mix-ICI1      9842
# 11mix-ICI1      9215
# GF-ICI1         7411
# GF-ICI1-plus    7145
# Name: count, dtype: int64

# %%
adata_solo[adata_solo.obs["condition"].isin(["GF"])].obs["sample_id"].value_counts()
# Out:
# sample_id
# GF-ICI2-plus    8508
# GF-ICI1         7411
# GF-ICI1-plus    7145
# GF-ICI2         5078
# Name: count, dtype: int64

# %%
adata_solo[adata_solo.obs["condition"].isin(["10mix"])].obs["sample_id"].value_counts()
# Out:
# sample_id
# 10mix-ICI1    9842
# 10mix-ICI2    8791
# Name: count, dtype: int64

# %%
adata_solo[adata_solo.obs["condition"].isin(["11mix"])].obs["sample_id"].value_counts()
# Out:
# sample_id
# 11mix-ICI1    9215
# 11mix-ICI2    8355
# Name: count, dtype: int64

# %%
def update_columns(row):
    if "10mix-ICI2" in row['sample_id']:
        row['condition'] = "10mix"
        row['batch_id'] = "ICI2"
    elif "10mix-ICI1" in row['sample_id']:
        row['condition'] = "10mix"
        row['batch_id'] = "ICI1"
    elif "11mix-ICI1" in row['sample_id']:
        row['condition'] = "11mix"
        row['batch_id'] = "ICI1"
    elif "11mix-ICI2" in row['sample_id']:
        row['condition'] = "11mix"
        row['batch_id'] = "ICI2"
    elif "GF-ICI1" in row['sample_id']:
        row['condition'] = "GF"
        row['batch_id'] = "ICI1"
    elif "GF-ICI2" in row['sample_id']:
        row['condition'] = "GF"
        row['batch_id'] = "ICI2"
    elif "GF-ICI1-plus " in row['sample_id']:
        row['condition'] = "GF-plus"
        row['batch_id'] = "ICI1"
    elif "GF-ICI2-plus " in row['sample_id']:
        row['condition'] = "GF-plus"
        row['batch_id'] = "ICI2"
    return row

# Apply the function to each row in the DataFrame
adata_solo.obs = adata_solo.obs.apply(update_columns, axis=1)

# %%
sc.pl.umap(adata_solo, color=["batch_id"], wspace=1)
# Out:
# /home/kvalem/.conda/envs/single_cell_sorted_scvi_2023/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata_solo, color=["condition"], wspace=1)
# Out:
# /home/kvalem/.conda/envs/single_cell_sorted_scvi_2023/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(
    adata_solo,
    color=["pct_counts_mt", "n_genes_by_counts"],
    cmap="inferno",
)

# %%
sc.pl.umap(adata_solo, color=["total_counts", "leiden"], vmax=10000, legend_loc="on data")
# Out:
# /home/kvalem/.conda/envs/single_cell_sorted_scvi_2023/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
def annot_empty_droplets(adata, boolean):
    import numpy as np
    
    if "is_droplet" not in adata.obs.columns:
        adata.obs["is_droplet"] = "cell"

    is_droplet = np.where(
        (adata.obs["is_droplet"] == "cell") & boolean, "cell", "droplet"
    )
    return is_droplet

# %%
# Remove empty droplets before scVI neighbors
adata_solo.obs["is_droplet"] = annot_empty_droplets(
    adata_solo,
    ~(
        (adata_solo.obs["leiden"].isin(["0","1","2","3","4","5","6"]))
        & (adata_solo.obs["total_counts"] < 2000)
        & (adata_solo.obs["n_genes_by_counts"] < 500)
    ),
)

# %%
adata_solo.obs["is_droplet"].value_counts()
# Out:
# is_droplet
# cell       62764
# droplet     1581
# Name: count, dtype: int64

# %%
sc.pl.umap(
    adata_solo[adata_solo.obs["leiden"].isin(["0"])],
    color=["pct_counts_mt", "n_genes_by_counts"],
    cmap="inferno",
)

sc.pl.umap(adata_solo[adata_solo.obs["leiden"].isin(["0"])], color=["total_counts", "leiden"], vmax=20000)
# Out:
# /home/kvalem/.conda/envs/single_cell_sorted_scvi_2023/lib/python3.10/site-packages/anndata/_core/anndata.py:1230: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/kvalem/.conda/envs/single_cell_sorted_scvi_2023/lib/python3.10/site-packages/anndata/_core/anndata.py:1230: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/kvalem/.conda/envs/single_cell_sorted_scvi_2023/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
