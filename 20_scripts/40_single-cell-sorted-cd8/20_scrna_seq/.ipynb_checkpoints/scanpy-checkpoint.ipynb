# %%
import gzip
import os
from functools import reduce
from pathlib import Path
import scipy

import anndata as ad
import numpy as np
import pandas as pd
import scanpy as sc
from scipy.sparse import csr_matrix
from tqdm.contrib.concurrent import process_map

# %%
pdata = sc.read_h5ad("pseudobulk.h5ad")
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
pdata
# Out:
# AnnData object with n_obs × n_vars = 91 × 12052
#     obs: '_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'is_doublet', 'is_outlier', 'leiden', 'origin', 'sample_id', 'value', 'condition', 'psbulk_n_cells', 'psbulk_counts'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     layers: 'psbulk_props'

# %%
# Import DESeq2
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

# %%
# Infer pathway activities with ulm
tf_acts, tf_pvals = dc.run_ulm(mat=mat, net=collectri)
tf_acts

# %%
pdata.var
# Out:
#                        ensembl_id    feature_types      gene_name     mt  \
# gene_name
# 0610009B22Rik  ENSMUSG00000007777  Gene Expression  0610009B22Rik  False
# 0610009L18Rik  ENSMUSG00000043644  Gene Expression  0610009L18Rik  False
# 0610010F05Rik  ENSMUSG00000042208  Gene Expression  0610010F05Rik  False
# 0610010K14Rik  ENSMUSG00000020831  Gene Expression  0610010K14Rik  False
# 0610012G03Rik  ENSMUSG00000107002  Gene Expression  0610012G03Rik  False
# ...                           ...              ...            ...    ...
# mt-Nd3         ENSMUSG00000064360  Gene Expression         mt-Nd3   True
# mt-Nd4         ENSMUSG00000064363  Gene Expression         mt-Nd4   True
# mt-Nd4l        ENSMUSG00000065947  Gene Expression        mt-Nd4l   True
# mt-Nd5         ENSMUSG00000064367  Gene Expression         mt-Nd5   True
# mt-Nd6         ENSMUSG00000064368  Gene Expression         mt-Nd6   True
#
#                 ribo  n_cells_by_counts  mean_counts  log1p_mean_counts  \
# gene_name
# 0610009B22Rik  False               1598     0.017656           0.017502
# 0610009L18Rik  False                158     0.001735           0.001733
# 0610010F05Rik  False                842     0.009454           0.009410
# 0610010K14Rik  False              16164     0.186314           0.170851
# 0610012G03Rik  False              18192     0.201665           0.183708
# ...              ...                ...          ...                ...
# mt-Nd3         False              54432     1.087239           0.735842
# mt-Nd4         False              65345     1.545678           0.934397
# mt-Nd4l        False              71221     5.045964           1.799391
# mt-Nd5         False              59245     1.277616           0.823129
# mt-Nd6         False               9593     0.108705           0.103193
#
#                pct_dropout_by_counts  total_counts  log1p_total_counts  \
# gene_name
# 0610009B22Rik              98.245344        1608.0            7.383368
# 0610009L18Rik              99.826511         158.0            5.068904
# 0610010F05Rik              99.075457         861.0            6.759255
# 0610010K14Rik              82.251405       16968.0            9.739143
# 0610012G03Rik              80.024596       18366.0            9.818311
# ...                              ...           ...                 ...
# mt-Nd3                     40.231904       99017.0           11.503057
# mt-Nd4                     28.249078      140768.0           11.854876
# mt-Nd4l                    21.797040      459546.0           13.037996
# mt-Nd5                     34.947075      116355.0           11.664410
# mt-Nd6                     89.466576        9900.0            9.200391
#
#                n_cells  n_counts  highly_variable  highly_variable_rank  \
# gene_name
# 0610009B22Rik     1584    1592.0            False                2157.0
# 0610009L18Rik      158     158.0            False                2067.0
# 0610010F05Rik      833     847.0            False                2278.0
# 0610010K14Rik    16102   16842.0            False                   NaN
# 0610012G03Rik    18137   18289.0            False                2808.0
# ...                ...       ...              ...                   ...
# mt-Nd3           54255   98516.0             True                 779.0
# mt-Nd4           65126  139991.0             True                 938.0
# mt-Nd4l          70904  457000.0             True                  76.0
# mt-Nd5           59050  115755.0             True                 447.0
# mt-Nd6            9559    9863.0            False                1758.0
#
#                   means  variances  variances_norm  highly_variable_nbatches
# gene_name
# 0610009B22Rik  0.091272   0.459027        0.878966                         1
# 0610009L18Rik  0.010155   0.057464        0.656943                         5
# 0610010F05Rik  0.048786   0.255377        0.892696                         3
# 0610010K14Rik  0.987764   4.428478        0.967449                         0
# 0610012G03Rik  1.135701   5.063442        0.985711                         2
# ...                 ...        ...             ...                       ...
# mt-Nd3         3.806022   9.577460        1.052526                        11
# mt-Nd4         4.696026   8.398152        0.979605                         9
# mt-Nd4l        5.894411   9.485419        1.125807                        10
# mt-Nd5         4.190438   9.225108        1.113372                        13
# mt-Nd6         0.611111   3.203827        1.030162                         7
#
# [12052 rows x 19 columns]

# %%
pdata.obs['leiden'] = pdata.obs['leiden'].astype('category')

# %%
sc.tl.rank_genes_groups(pdata, 'leiden', method='wilcoxon')
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: overflow encountered in expm1
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:418: RuntimeWarning: overflow encountered in expm1
#   self.expm1_func(mean_rest) + 1e-9
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: invalid value encountered in divide
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: divide by zero encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: overflow encountered in expm1
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:418: RuntimeWarning: overflow encountered in expm1
#   self.expm1_func(mean_rest) + 1e-9
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: invalid value encountered in divide
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: divide by zero encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: overflow encountered in expm1
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:418: RuntimeWarning: overflow encountered in expm1
#   self.expm1_func(mean_rest) + 1e-9
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: invalid value encountered in divide
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: divide by zero encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: overflow encountered in expm1
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:418: RuntimeWarning: overflow encountered in expm1
#   self.expm1_func(mean_rest) + 1e-9
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: invalid value encountered in divide
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: divide by zero encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: overflow encountered in expm1
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:418: RuntimeWarning: overflow encountered in expm1
#   self.expm1_func(mean_rest) + 1e-9
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: invalid value encountered in divide
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: divide by zero encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: overflow encountered in expm1
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:418: RuntimeWarning: overflow encountered in expm1
#   self.expm1_func(mean_rest) + 1e-9
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:417: RuntimeWarning: invalid value encountered in divide
#   foldchanges = (self.expm1_func(mean_group) + 1e-9) / (
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: divide by zero encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:418: RuntimeWarning: overflow encountered in expm1
#   self.expm1_func(mean_rest) + 1e-9
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: divide by zero encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(

# %%
pdata.obs.leiden.value_counts()
# Out:
# 0    14
# 1    14
# 2    14
# 3    14
# 4    14
# 5    13
# 6     8
# Name: leiden, dtype: int64

# %%
gene_list_ranked = sc.get.rank_genes_groups_df(pdata, group=None,key="rank_genes_groups", gene_symbols="gene_name").dropna().head(50)
display(gene_list_ranked[["gene_name", "pvals_adj"]])
# Out:
#         gene_name  pvals_adj
# 0           Csrp2   0.000011
# 1        Hist1h3i   0.000011
# 2            Grb7   0.000011
# 3            Rhoc   0.000011
# 4            Car2   0.000011
# 5         Bcl2a1d   0.000011
# 6           Abhd4   0.000011
# 7            Areg   0.000011
# 8           Trib1   0.000011
# 9         Gm46620   0.000011
# 10        Slc39a4   0.000011
# 11        Mfsd13a   0.000011
# 12      Gabarapl1   0.000011
# 13         Slc2a8   0.000011
# 14         Ccdc30   0.000011
# 15       Hist1h4i   0.000011
# 16         Nudt18   0.000011
# 17         Stradb   0.000011
# 18           Hccs   0.000011
# 19          Smco4   0.000011
# 20          Tstd3   0.000011
# 21         Tlnrd1   0.000011
# 22            Trf   0.000011
# 23        Gm45716   0.000011
# 24          Decr1   0.000011
# 25           Prr7   0.000011
# 26         Mthfsd   0.000011
# 27       Tmem191c   0.000011
# 28          Lime1   0.000011
# 29           Bak1   0.000011
# 30       AI854703   0.000011
# 31          Fads1   0.000011
# 32         Siah1b   0.000011
# 33       Ctnnbip1   0.000011
# 34  6330403K07Rik   0.000011
# 35          Fbxo6   0.000011
# 36          Smim3   0.000011
# 37         Plscr1   0.000011
# 38          Prrt1   0.000011
# 39          Hspa2   0.000011
# 40       Pdcd1lg2   0.000011
# 41          Armt1   0.000011
# 42        Slc35a2   0.000011
# 43           Srrd   0.000011
# 44       Hist1h3f   0.000011
# 45           H1f0   0.000011
# 46           Cptp   0.000011
# 47          Fabp5   0.000011
# 48          Ppil1   0.000011
# 49         Vcpkmt   0.000011

# %%
import scanpy_helpers as sh

# %%
ah.plot_dotplot(adata_m)

# %%
path = "/data/projects/2021/MicrobialMetabolites/single-cell-sorted-cd8/results/solo"

# %%
adata_solo = sc.read_h5ad(f"{path}/adata_nodoublet.h5ad")
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata_solo_int = sc.read_h5ad("/data/projects/2021/MicrobialMetabolites/single-cell-sorted-cd8/results/adata_solo_integrated.h5ad")
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata_solo_int.var
# Out:
#                         ensembl_id    feature_types       gene_name     mt  \
# gene_name
# Mrpl15          ENSMUSG00000033845  Gene Expression          Mrpl15  False
# Lypla1          ENSMUSG00000025903  Gene Expression          Lypla1  False
# Tcea1           ENSMUSG00000033813  Gene Expression           Tcea1  False
# Atp6v1h         ENSMUSG00000033793  Gene Expression         Atp6v1h  False
# Rb1cc1          ENSMUSG00000025907  Gene Expression          Rb1cc1  False
# ...                            ...              ...             ...    ...
# CAAA01118383.1  ENSMUSG00000063897  Gene Expression  CAAA01118383.1  False
# Vamp7           ENSMUSG00000051412  Gene Expression           Vamp7  False
# Tmlhe           ENSMUSG00000079834  Gene Expression           Tmlhe  False
# CAAA01147332.1  ENSMUSG00000095742  Gene Expression  CAAA01147332.1  False
# AC149090.1      ENSMUSG00000095041  Gene Expression      AC149090.1  False
#
#                  ribo  n_cells_by_counts  mean_counts  log1p_mean_counts  \
# gene_name
# Mrpl15          False              21544     0.265735           0.235653
# Lypla1          False              19780     0.223208           0.201477
# Tcea1           False              40520     0.502943           0.407425
# Atp6v1h         False              14525     0.160082           0.148491
# Rb1cc1          False              21173     0.236022           0.211898
# ...               ...                ...          ...                ...
# CAAA01118383.1  False               9796     0.108013           0.102569
# Vamp7           False               6678     0.073766           0.071172
# Tmlhe           False                593     0.006577           0.006556
# CAAA01147332.1  False              20856     0.302091           0.263971
# AC149090.1      False              29796     0.361714           0.308744
#
#                 pct_dropout_by_counts  total_counts  log1p_total_counts  \
# gene_name
# Mrpl15                      76.343992       24201.0           10.094191
# Lypla1                      78.280921       20328.0            9.919804
# Tcea1                       55.507730       45804.0           10.732148
# Atp6v1h                     84.051080       14579.0            9.587406
# Rb1cc1                      76.751362       21495.0            9.975622
# ...                               ...           ...                 ...
# CAAA01118383.1              89.243675        9837.0            9.194008
# Vamp7                       92.667340        6718.0            8.812695
# Tmlhe                       99.348867         599.0            6.396930
# CAAA01147332.1              77.099438       27512.0           10.222414
# AC149090.1                  67.283029       32942.0           10.402534
#
#                 n_cells  n_counts  highly_variable  highly_variable_rank  \
# gene_name
# Mrpl15            21484   24002.0            False                   NaN
# Lypla1            19725   20230.0            False                   NaN
# Tcea1             40436   45545.0            False                   NaN
# Atp6v1h           14481   14530.0            False                3409.5
# Rb1cc1            21130   21450.0            False                2045.0
# ...                 ...       ...              ...                   ...
# CAAA01118383.1     9764    9803.0            False                2894.0
# Vamp7              6640    6672.0            False                2992.0
# Tmlhe               592     598.0             True                 978.0
# CAAA01147332.1    20802   27325.0            False                2826.0
# AC149090.1        29748   32886.0            False                2257.0
#
#                    means  variances  variances_norm  highly_variable_nbatches
# gene_name
# Mrpl15          1.327405   5.528502        0.963611                         0
# Lypla1          1.222800   5.273152        0.967138                         0
# Tcea1           2.598504   8.122003        0.966765                         0
# Atp6v1h         0.916394   4.352974        0.998627                         2
# Rb1cc1          1.386223   6.238710        1.023630                         8
# ...                  ...        ...             ...                       ...
# CAAA01118383.1  0.614820   3.085952        0.994008                         1
# Vamp7           0.401343   2.003972        0.963557                         1
# Tmlhe           0.039054   0.227810        0.900718                         9
# CAAA01147332.1  1.305978   5.596172        0.974313                         1
# AC149090.1      1.951420   7.746954        1.028681                        11
#
# [12052 rows x 19 columns]

# %%
# marker genes 
marker_genes= pd.read_csv("/data/scratch/kvalem/projects/2021/microbial-metabolites/tables/40_single-cell-sorted-cd8/marker_genes_cd8t_cells.csv")

# %%
def sentence_case(text):
    return text.capitalize()

# %%
marker_genes['gene'] = marker_genes['gene'].apply(sentence_case)

# %%
marker_genes
# Out:
#              cluster    gene  avg_logFC         p_val     p_val_adj  pct.1  \
# 0       CD8_c0_tTeff    Lmna   0.695375  0.000000e+00  0.000000e+00  0.280
# 1       CD8_c0_tTeff   Zfp36   0.681179  0.000000e+00  0.000000e+00  0.768
# 2       CD8_c0_tTeff    Rgcc   0.619963  0.000000e+00  0.000000e+00  0.449
# 3       CD8_c0_tTeff   Cxcr4   0.583576  0.000000e+00  0.000000e+00  0.862
# 4       CD8_c0_tTeff   Dusp2   0.575664  0.000000e+00  0.000000e+00  0.731
# ..               ...     ...        ...           ...           ...    ...
# 670  CD8_c13_Tn_TCF7   Rcan3   0.736364  1.850000e-41  1.450000e-36  0.302
# 671  CD8_c13_Tn_TCF7  Pabpc4   0.722169  1.900000e-36  1.490000e-31  0.250
# 672  CD8_c13_Tn_TCF7   Mllt6   0.719908  1.060000e-28  8.290000e-24  0.280
# 673  CD8_c13_Tn_TCF7  Pou2f2   0.713540  3.430000e-30  2.690000e-25  0.151
# 674  CD8_c13_Tn_TCF7  Pou2f2   0.713540  3.430000e-30  2.690000e-25  0.151
#
#      pct.2
# 0    0.139
# 1    0.599
# 2    0.311
# 3    0.717
# 4    0.516
# ..     ...
# 670  0.167
# 671  0.131
# 672  0.173
# 673  0.064
# 674  0.064
#
# [675 rows x 7 columns]

# %%
split_columns = marker_genes['cluster'].str.split('_', expand=True)
split_columns.columns = ['CD8', 'cluster', 'cell','genes']
# Concatenate the split columns with the original DataFrame
marker_genes = pd.concat([marker_genes, split_columns], axis=1)

# %%
marker_genes
# Out:
#              cluster    gene  avg_logFC         p_val     p_val_adj  pct.1  \
# 0       CD8_c0_tTeff    Lmna   0.695375  0.000000e+00  0.000000e+00  0.280
# 1       CD8_c0_tTeff   Zfp36   0.681179  0.000000e+00  0.000000e+00  0.768
# 2       CD8_c0_tTeff    Rgcc   0.619963  0.000000e+00  0.000000e+00  0.449
# 3       CD8_c0_tTeff   Cxcr4   0.583576  0.000000e+00  0.000000e+00  0.862
# 4       CD8_c0_tTeff   Dusp2   0.575664  0.000000e+00  0.000000e+00  0.731
# ..               ...     ...        ...           ...           ...    ...
# 670  CD8_c13_Tn_TCF7   Rcan3   0.736364  1.850000e-41  1.450000e-36  0.302
# 671  CD8_c13_Tn_TCF7  Pabpc4   0.722169  1.900000e-36  1.490000e-31  0.250
# 672  CD8_c13_Tn_TCF7   Mllt6   0.719908  1.060000e-28  8.290000e-24  0.280
# 673  CD8_c13_Tn_TCF7  Pou2f2   0.713540  3.430000e-30  2.690000e-25  0.151
# 674  CD8_c13_Tn_TCF7  Pou2f2   0.713540  3.430000e-30  2.690000e-25  0.151
#
#      pct.2  CD8 cluster   cell genes
# 0    0.139  CD8      c0  tTeff  None
# 1    0.599  CD8      c0  tTeff  None
# 2    0.311  CD8      c0  tTeff  None
# 3    0.717  CD8      c0  tTeff  None
# 4    0.516  CD8      c0  tTeff  None
# ..     ...  ...     ...    ...   ...
# 670  0.167  CD8     c13     Tn  TCF7
# 671  0.131  CD8     c13     Tn  TCF7
# 672  0.173  CD8     c13     Tn  TCF7
# 673  0.064  CD8     c13     Tn  TCF7
# 674  0.064  CD8     c13     Tn  TCF7
#
# [675 rows x 11 columns]

# %%
marker_genes.rename(columns={"gene":"genesymbol","cell":"cell_type"}, inplace = True)

# %%
marker_genes
# Out:
#              cluster genesymbol  avg_logFC         p_val     p_val_adj  pct.1  \
# 0       CD8_c0_tTeff       Lmna   0.695375  0.000000e+00  0.000000e+00  0.280
# 1       CD8_c0_tTeff      Zfp36   0.681179  0.000000e+00  0.000000e+00  0.768
# 2       CD8_c0_tTeff       Rgcc   0.619963  0.000000e+00  0.000000e+00  0.449
# 3       CD8_c0_tTeff      Cxcr4   0.583576  0.000000e+00  0.000000e+00  0.862
# 4       CD8_c0_tTeff      Dusp2   0.575664  0.000000e+00  0.000000e+00  0.731
# ..               ...        ...        ...           ...           ...    ...
# 670  CD8_c13_Tn_TCF7      Rcan3   0.736364  1.850000e-41  1.450000e-36  0.302
# 671  CD8_c13_Tn_TCF7     Pabpc4   0.722169  1.900000e-36  1.490000e-31  0.250
# 672  CD8_c13_Tn_TCF7      Mllt6   0.719908  1.060000e-28  8.290000e-24  0.280
# 673  CD8_c13_Tn_TCF7     Pou2f2   0.713540  3.430000e-30  2.690000e-25  0.151
# 674  CD8_c13_Tn_TCF7     Pou2f2   0.713540  3.430000e-30  2.690000e-25  0.151
#
#      pct.2  CD8 cluster cell_type genes
# 0    0.139  CD8      c0     tTeff  None
# 1    0.599  CD8      c0     tTeff  None
# 2    0.311  CD8      c0     tTeff  None
# 3    0.717  CD8      c0     tTeff  None
# 4    0.516  CD8      c0     tTeff  None
# ..     ...  ...     ...       ...   ...
# 670  0.167  CD8     c13        Tn  TCF7
# 671  0.131  CD8     c13        Tn  TCF7
# 672  0.173  CD8     c13        Tn  TCF7
# 673  0.064  CD8     c13        Tn  TCF7
# 674  0.064  CD8     c13        Tn  TCF7
#
# [675 rows x 11 columns]

# %%
marker_genes = marker_genes.drop_duplicates(subset=['genesymbol'])

# %%
marker_genes.rename(columns={"genesymbol":"gene_identifier"}, inplace = True)
# Out:
# /tmp/ipykernel_59346/221420390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker_genes.rename(columns={"genesymbol":"gene_identifier"}, inplace = True)

# %%
marker_genes
# Out:
#              cluster gene_identifier  avg_logFC         p_val     p_val_adj  \
# 0       CD8_c0_tTeff            Lmna   0.695375  0.000000e+00  0.000000e+00
# 1       CD8_c0_tTeff           Zfp36   0.681179  0.000000e+00  0.000000e+00
# 2       CD8_c0_tTeff            Rgcc   0.619963  0.000000e+00  0.000000e+00
# 3       CD8_c0_tTeff           Cxcr4   0.583576  0.000000e+00  0.000000e+00
# 4       CD8_c0_tTeff           Dusp2   0.575664  0.000000e+00  0.000000e+00
# ..               ...             ...        ...           ...           ...
# 668  CD8_c13_Tn_TCF7           44448   0.750838  7.710000e-48  6.040000e-43
# 669  CD8_c13_Tn_TCF7            Grk2   0.747509  4.130000e-61  3.230000e-56
# 671  CD8_c13_Tn_TCF7          Pabpc4   0.722169  1.900000e-36  1.490000e-31
# 672  CD8_c13_Tn_TCF7           Mllt6   0.719908  1.060000e-28  8.290000e-24
# 673  CD8_c13_Tn_TCF7          Pou2f2   0.713540  3.430000e-30  2.690000e-25
#
#      pct.1  pct.2  CD8 cluster cell_type genes
# 0    0.280  0.139  CD8      c0     tTeff  None
# 1    0.768  0.599  CD8      c0     tTeff  None
# 2    0.449  0.311  CD8      c0     tTeff  None
# 3    0.862  0.717  CD8      c0     tTeff  None
# 4    0.731  0.516  CD8      c0     tTeff  None
# ..     ...    ...  ...     ...       ...   ...
# 668  0.492  0.366  CD8     c13        Tn  TCF7
# 669  0.239  0.092  CD8     c13        Tn  TCF7
# 671  0.250  0.131  CD8     c13        Tn  TCF7
# 672  0.280  0.173  CD8     c13        Tn  TCF7
# 673  0.151  0.064  CD8     c13        Tn  TCF7
#
# [517 rows x 11 columns]

# %%
marker_genes_ss = marker_genes[['cell_type', 'gene_identifier']]

# %%
marker_genes_ss
# Out:
#     cell_type gene_identifier
# 0       tTeff            Lmna
# 1       tTeff           Zfp36
# 2       tTeff            Rgcc
# 3       tTeff           Cxcr4
# 4       tTeff           Dusp2
# ..        ...             ...
# 668        Tn           44448
# 669        Tn            Grk2
# 671        Tn          Pabpc4
# 672        Tn           Mllt6
# 673        Tn          Pou2f2
#
# [517 rows x 2 columns]

# %%
ah = sh.annotation.AnnotationHelper(markers=marker_genes_ss)

# %%
adata_solo.var_names_make_unique()

# %%
acts = sc.read_h5ad("acts.h5ad")

# %%
sc.pp.scale(acts)
acts
# Out:
# AnnData object with n_obs × n_vars = 74491 × 10
#     obs: '_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'is_doublet', 'is_outlier', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_mito', 'is_outlier_top_20', 'leiden', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'log1p_total_counts_ribo', 'n_counts', 'n_genes', 'n_genes_by_counts', 'origin', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'sample_id', 'total_counts', 'total_counts_mt', 'total_counts_ribo', 'value', 'condition'
#     var: 'mean', 'std'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected', 'ora_estimate', 'ora_pvals'

# %%
chemokine_receptor_genes = ["CCR4","CCR5","CCR7","CXCR3","CXCR4","CXCR5","CXCR6","CCL3","CCL4","CCL5","CXCL8","XCL1","XCL2","CXCL2","CXCL9","CXCL1","CXCL10"]
chemokine_receptor_genes_sentence_case = [item.capitalize() for item in chemokine_receptor_genes]

# %%
genes_in_adata = adata_solo[:, adata_solo.var.gene_name.isin(chemokine_receptor_genes_sentence_case)].var.gene_name.to_list()

# %%
genes_in_adata
# Out:
# ['Cxcr4',
#  'Xcl1',
#  'Cxcl10',
#  'Cxcr5',
#  'Ccr4',
#  'Cxcr6',
#  'Ccr5',
#  'Ccl5',
#  'Ccl3',
#  'Ccl4',
#  'Ccr7',
#  'Cxcr3']

# %%
genes_in_adata
# Out:
# ['Cxcr4',
#  'Xcl1',
#  'Cxcl10',
#  'Cxcr5',
#  'Ccr4',
#  'Cxcr6',
#  'Ccr5',
#  'Ccl5',
#  'Ccl3',
#  'Ccl4',
#  'Ccr7',
#  'Cxcr3']

# %%
adata_solo
# Out:
# AnnData object with n_obs × n_vars = 74491 × 12052
#     obs: 'sample_id', 'batch', 'n_counts', 'n_genes', 'value', '_scvi_batch', '_scvi_labels', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_top_20', 'is_outlier_mito', 'is_outlier', 'is_doublet', 'leiden'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
def update_columns(row):
   
    if "ICI" not in row['sample_id']:
        row['origin'] = "colon"
    else:
         row['origin'] = "til"
        
    return row

# Apply the function to each row in the DataFrame
adata_solo.obs = adata_solo.obs.apply(update_columns, axis=1)

# %%
def update_columns(row):
   
    if "ICI1"  in row['sample_id']:
        row['batch_id'] = "ICI1"
    elif "ICI2" in row['sample_id']:
         row['batch_id'] = "ICI2"
    elif row['sample_id'] == "10mix1":
        row['batch_id'] = "1"
    elif row['sample_id'] == "10mix2":
         row['batch_id'] = "2"
        
        
    return row

# Apply the function to each row in the DataFrame
adata_solo.obs = adata_solo.obs.apply(update_columns, axis=1)

# %%
def update_columns(row):
   
    if row['sample_id'] == "10mix1":
        row['condition'] = "10mix"
    elif row['sample_id'] == "10mix2":
         row['condition'] = "10mix"
    elif row['sample_id'] == "11mix1":
         row['condition'] = "11mix"
    elif row['sample_id'] == "11mix2":
         row['condition'] = "11mix"
    elif row['sample_id'] == "GF1":
         row['condition'] = "GF"
    elif row['sample_id'] == "GF2":
         row['condition'] = "GF"
    elif row['sample_id'] == "GF-ICI2-plus":
         row['condition'] = "GF-plus"
    elif row['sample_id'] == "GF-ICI1-plus":
         row['condition'] = "GF-plus"
    elif row['sample_id'] == "GF-ICI2":
         row['condition'] = "GF"
    elif row['sample_id'] == "GF-ICI1":
         row['condition'] = "GF"
    elif row['sample_id'] == "10mix-ICI1":
         row['condition'] = "10mix"
    elif row['sample_id'] == "10mix-ICI2":
         row['condition'] = "10mix"
    elif row['sample_id'] == "11mix-ICI1":
         row['condition'] = "11mix"
    elif row['sample_id'] == "11mix-ICI2":
         row['condition'] = "11mix"
    
    
        
        
    return row

# Apply the function to each row in the DataFrame
adata_solo.obs = adata_solo.obs.apply(update_columns, axis=1)

# %%
adata_11mix = adata_solo[adata_solo.obs["sample_id"].isin(["11mix1","11mix2"])]

# %%
adata_10mix = adata_solo[adata_solo.obs["sample_id"].isin(["10mix1","10mix2"])]

# %%
adata_GF = adata_solo[adata_solo.obs["sample_id"].isin(["GF1","GF2"])]

# %%
adata_11mixici = adata_solo[adata_solo.obs["sample_id"].isin(["11mix-ICI1","11mixICI2"])]

# %%
adata_10mixici = adata_solo[adata_solo.obs["sample_id"].isin(["10mix-ICI1","10mix-ICI2"])]

# %%
adata_GFici = adata_solo[adata_solo.obs["sample_id"].isin(["GF-ICI1","GF-ICI2"])]

# %%
adata_GFiciplus = adata_solo[adata_solo.obs["sample_id"].isin(["GF-ICI1-plus","GF-ICI2-plus"])]

# %%
adata_til = adata_solo[adata_solo.obs["origin"].isin(["til"])]

# %%
adata_colon = adata_solo[adata_solo.obs["origin"].isin(["colon"])]

# %%
gene_name = "Cxcr3"
# Check if the gene is present in adata.var
if gene_name in adata_11mix.var_names:
    # Get the index of the gene in adata.var
    gene_index = adata_11mix.var_names.get_loc(gene_name)

    # Filter rows in adata.X based on the presence of the gene
    gene_expression = adata_11mix.X[:, gene_index]

    # Count the number of non-zero entries (presence of the gene)
    num_rows_with_gene = (gene_expression > 0).sum()

    print(f"Number of rows with {gene_name}: {num_rows_with_gene}")
else:
    print(f"{gene_name} not found in adata.var")
# Out:
# Number of rows with Cxcr3: 1111

# %%
gene_name = "Cxcr3"
# Check if the gene is present in adata.var
if gene_name in adata_10mix.var_names:
    # Get the index of the gene in adata.var
    gene_index = adata_10mix.var_names.get_loc(gene_name)

    # Filter rows in adata.X based on the presence of the gene
    gene_expression = adata_10mix.X[:, gene_index]

    # Count the number of non-zero entries (presence of the gene)
    num_rows_with_gene = (gene_expression > 0).sum()

    print(f"Number of rows with {gene_name}: {num_rows_with_gene}")
else:
    print(f"{gene_name} not found in adata.var")
# Out:
# Number of rows with Cxcr3: 826

# %%
gene_name = "Cxcr3"
# Check if the gene is present in adata.var
if gene_name in adata_GF.var_names:
    # Get the index of the gene in adata.var
    gene_index = adata_GF.var_names.get_loc(gene_name)

    # Filter rows in adata.X based on the presence of the gene
    gene_expression = adata_GF.X[:, gene_index]

    # Count the number of non-zero entries (presence of the gene)
    num_rows_with_gene = (gene_expression > 0).sum()

    print(f"Number of rows with {gene_name}: {num_rows_with_gene}")
else:
    print(f"{gene_name} not found in adata.var")
# Out:
# Number of rows with Cxcr3: 175

# %%
gene_name = "Cxcl10"
# Check if the gene is present in adata.var
if gene_name in adata_colon.var_names:
    # Get the index of the gene in adata.var
    gene_index = adata_colon.var_names.get_loc(gene_name)

    # Filter rows in adata.X based on the presence of the gene
    gene_expression = adata_colon.X[:, gene_index]

    # Count the number of non-zero entries (presence of the gene)
    num_rows_with_gene = (gene_expression > 0).sum()

    print(f"Number of rows with {gene_name}: {num_rows_with_gene}")
else:
    print(f"{gene_name} not found in adata.var")
# Out:
# Number of rows with Cxcl10: 1731

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["10mix1","10mix2","11mix1","11mix2","GF1","GF2"])],color="cell_type",legend_loc="on data", frameon=False)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
if "Cxcr2" in adata_solo.var:
    print("T")

# %%
adata_solo.var.index = adata_solo.var.gene_name

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["11mix1","11mix2"])], color="Cxcr2", frameon=False)

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["GF1","GF2"])], color="Cxcr3", frameon=False)

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["10mix1","10mix2"])], color="Cxcr3", frameon=False)

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["11mix-ICI1","11mix-ICI2"])], color="Cxcr3", frameon=False)

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["GF-ICI1","GF-ICI2"])], color="Cxcr3", frameon=False)

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["GF-ICI1-plus","GF-ICI2-plus"])], color="Cxcr3", frameon=False)

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["10mix-ICI1","10mix-ICI2"])], color="Cxcr3", frameon=False)

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["10mix-ICI1","10mix-ICI2","GF-ICI1-plus","GF-ICI2-plus","GF-ICI1","GF-ICI2","11mix-ICI1","11mix-ICI2"])], color="Cxcr3", frameon=False)

# %%
sc.pl.umap(adata_solo[adata_solo.obs["sample_id"].isin(["10mix1","10mix2","GF1","GF2","11mix1","11mix2"])], color="Cxcr3", frameon=False)

# %%
if "Cxcl10" in adata_solo_int.var.index:
    print("T")
# Out:
# T

# %%
adata_solo.obs.columns
# Out:
# Index(['_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'is_doublet',
#        'is_outlier', 'is_outlier_counts', 'is_outlier_genes',
#        'is_outlier_mito', 'is_outlier_top_20', 'leiden',
#        'log1p_n_genes_by_counts', 'log1p_total_counts',
#        'log1p_total_counts_mt', 'log1p_total_counts_ribo', 'n_counts',
#        'n_genes', 'n_genes_by_counts', 'origin', 'pct_counts_in_top_20_genes',
#        'pct_counts_mt', 'pct_counts_ribo', 'sample_id', 'total_counts',
#        'total_counts_mt', 'total_counts_ribo', 'value', 'condition'],
#       dtype='object')

# %%
sc.pl.umap(adata_solo[adata_solo.obs["cell_type"]], color="Cxcl10", frameon=False)

# %%
"CXCL2","CXCL9","CXCL1","CXCL10"

# %%
genes_in_adata
# Out:
# ['Cxcr4',
#  'Xcl1',
#  'Cxcl10',
#  'Cxcr5',
#  'Ccr4',
#  'Cxcr6',
#  'Ccr5',
#  'Ccl5',
#  'Ccl3',
#  'Ccl4',
#  'Ccr7',
#  'Cxcr3']

# %%
adata_solo.var.index = adata_solo.var.ensembl_id

# %%
adata_11mix.var
# Out:
#                         ensembl_id    feature_types       gene_name     mt  \
# gene_name
# Mrpl15          ENSMUSG00000033845  Gene Expression          Mrpl15  False
# Lypla1          ENSMUSG00000025903  Gene Expression          Lypla1  False
# Tcea1           ENSMUSG00000033813  Gene Expression           Tcea1  False
# Atp6v1h         ENSMUSG00000033793  Gene Expression         Atp6v1h  False
# Rb1cc1          ENSMUSG00000025907  Gene Expression          Rb1cc1  False
# ...                            ...              ...             ...    ...
# CAAA01118383.1  ENSMUSG00000063897  Gene Expression  CAAA01118383.1  False
# Vamp7           ENSMUSG00000051412  Gene Expression           Vamp7  False
# Tmlhe           ENSMUSG00000079834  Gene Expression           Tmlhe  False
# CAAA01147332.1  ENSMUSG00000095742  Gene Expression  CAAA01147332.1  False
# AC149090.1      ENSMUSG00000095041  Gene Expression      AC149090.1  False
#
#                  ribo  n_cells_by_counts  mean_counts  log1p_mean_counts  \
# gene_name
# Mrpl15          False              21544     0.265735           0.235653
# Lypla1          False              19780     0.223208           0.201477
# Tcea1           False              40520     0.502943           0.407425
# Atp6v1h         False              14525     0.160082           0.148491
# Rb1cc1          False              21173     0.236022           0.211898
# ...               ...                ...          ...                ...
# CAAA01118383.1  False               9796     0.108013           0.102569
# Vamp7           False               6678     0.073766           0.071172
# Tmlhe           False                593     0.006577           0.006556
# CAAA01147332.1  False              20856     0.302091           0.263971
# AC149090.1      False              29796     0.361714           0.308744
#
#                 pct_dropout_by_counts  total_counts  log1p_total_counts  \
# gene_name
# Mrpl15                      76.343992       24201.0           10.094191
# Lypla1                      78.280921       20328.0            9.919804
# Tcea1                       55.507730       45804.0           10.732148
# Atp6v1h                     84.051080       14579.0            9.587406
# Rb1cc1                      76.751362       21495.0            9.975622
# ...                               ...           ...                 ...
# CAAA01118383.1              89.243675        9837.0            9.194008
# Vamp7                       92.667340        6718.0            8.812695
# Tmlhe                       99.348867         599.0            6.396930
# CAAA01147332.1              77.099438       27512.0           10.222414
# AC149090.1                  67.283029       32942.0           10.402534
#
#                 n_cells  n_counts  highly_variable  highly_variable_rank  \
# gene_name
# Mrpl15            21484   24002.0            False                   NaN
# Lypla1            19725   20230.0            False                   NaN
# Tcea1             40436   45545.0            False                   NaN
# Atp6v1h           14481   14530.0            False                3409.5
# Rb1cc1            21130   21450.0            False                2045.0
# ...                 ...       ...              ...                   ...
# CAAA01118383.1     9764    9803.0            False                2894.0
# Vamp7              6640    6672.0            False                2992.0
# Tmlhe               592     598.0             True                 978.0
# CAAA01147332.1    20802   27325.0            False                2826.0
# AC149090.1        29748   32886.0            False                2257.0
#
#                    means  variances  variances_norm  highly_variable_nbatches
# gene_name
# Mrpl15          1.327405   5.528502        0.963611                         0
# Lypla1          1.222800   5.273152        0.967138                         0
# Tcea1           2.598504   8.122003        0.966765                         0
# Atp6v1h         0.916394   4.352974        0.998627                         2
# Rb1cc1          1.386223   6.238710        1.023630                         8
# ...                  ...        ...             ...                       ...
# CAAA01118383.1  0.614820   3.085952        0.994008                         1
# Vamp7           0.401343   2.003972        0.963557                         1
# Tmlhe           0.039054   0.227810        0.900718                         9
# CAAA01147332.1  1.305978   5.596172        0.974313                         1
# AC149090.1      1.951420   7.746954        1.028681                        11
#
# [12052 rows x 19 columns]

# %%
adata_solo.var
# Out:
#                             ensembl_id    feature_types       gene_name  \
# ensembl_id
# ENSMUSG00000033845  ENSMUSG00000033845  Gene Expression          Mrpl15
# ENSMUSG00000025903  ENSMUSG00000025903  Gene Expression          Lypla1
# ENSMUSG00000033813  ENSMUSG00000033813  Gene Expression           Tcea1
# ENSMUSG00000033793  ENSMUSG00000033793  Gene Expression         Atp6v1h
# ENSMUSG00000025907  ENSMUSG00000025907  Gene Expression          Rb1cc1
# ...                                ...              ...             ...
# ENSMUSG00000063897  ENSMUSG00000063897  Gene Expression  CAAA01118383.1
# ENSMUSG00000051412  ENSMUSG00000051412  Gene Expression           Vamp7
# ENSMUSG00000079834  ENSMUSG00000079834  Gene Expression           Tmlhe
# ENSMUSG00000095742  ENSMUSG00000095742  Gene Expression  CAAA01147332.1
# ENSMUSG00000095041  ENSMUSG00000095041  Gene Expression      AC149090.1
#
#                        mt   ribo  n_cells_by_counts  mean_counts  \
# ensembl_id
# ENSMUSG00000033845  False  False              21544     0.265735
# ENSMUSG00000025903  False  False              19780     0.223208
# ENSMUSG00000033813  False  False              40520     0.502943
# ENSMUSG00000033793  False  False              14525     0.160082
# ENSMUSG00000025907  False  False              21173     0.236022
# ...                   ...    ...                ...          ...
# ENSMUSG00000063897  False  False               9796     0.108013
# ENSMUSG00000051412  False  False               6678     0.073766
# ENSMUSG00000079834  False  False                593     0.006577
# ENSMUSG00000095742  False  False              20856     0.302091
# ENSMUSG00000095041  False  False              29796     0.361714
#
#                     log1p_mean_counts  pct_dropout_by_counts  total_counts  \
# ensembl_id
# ENSMUSG00000033845           0.235653              76.343992       24201.0
# ENSMUSG00000025903           0.201477              78.280921       20328.0
# ENSMUSG00000033813           0.407425              55.507730       45804.0
# ENSMUSG00000033793           0.148491              84.051080       14579.0
# ENSMUSG00000025907           0.211898              76.751362       21495.0
# ...                               ...                    ...           ...
# ENSMUSG00000063897           0.102569              89.243675        9837.0
# ENSMUSG00000051412           0.071172              92.667340        6718.0
# ENSMUSG00000079834           0.006556              99.348867         599.0
# ENSMUSG00000095742           0.263971              77.099438       27512.0
# ENSMUSG00000095041           0.308744              67.283029       32942.0
#
#                     log1p_total_counts  n_cells  n_counts  highly_variable  \
# ensembl_id
# ENSMUSG00000033845           10.094191    21484   24002.0            False
# ENSMUSG00000025903            9.919804    19725   20230.0            False
# ENSMUSG00000033813           10.732148    40436   45545.0            False
# ENSMUSG00000033793            9.587406    14481   14530.0            False
# ENSMUSG00000025907            9.975622    21130   21450.0            False
# ...                                ...      ...       ...              ...
# ENSMUSG00000063897            9.194008     9764    9803.0            False
# ENSMUSG00000051412            8.812695     6640    6672.0            False
# ENSMUSG00000079834            6.396930      592     598.0             True
# ENSMUSG00000095742           10.222414    20802   27325.0            False
# ENSMUSG00000095041           10.402534    29748   32886.0            False
#
#                     highly_variable_rank     means  variances  variances_norm  \
# ensembl_id
# ENSMUSG00000033845                   NaN  1.327405   5.528502        0.963611
# ENSMUSG00000025903                   NaN  1.222800   5.273152        0.967138
# ENSMUSG00000033813                   NaN  2.598504   8.122003        0.966765
# ENSMUSG00000033793                3409.5  0.916394   4.352974        0.998627
# ENSMUSG00000025907                2045.0  1.386223   6.238710        1.023630
# ...                                  ...       ...        ...             ...
# ENSMUSG00000063897                2894.0  0.614820   3.085952        0.994008
# ENSMUSG00000051412                2992.0  0.401343   2.003972        0.963557
# ENSMUSG00000079834                 978.0  0.039054   0.227810        0.900718
# ENSMUSG00000095742                2826.0  1.305978   5.596172        0.974313
# ENSMUSG00000095041                2257.0  1.951420   7.746954        1.028681
#
#                     highly_variable_nbatches
# ensembl_id
# ENSMUSG00000033845                         0
# ENSMUSG00000025903                         0
# ENSMUSG00000033813                         0
# ENSMUSG00000033793                         2
# ENSMUSG00000025907                         8
# ...                                      ...
# ENSMUSG00000063897                         1
# ENSMUSG00000051412                         1
# ENSMUSG00000079834                         9
# ENSMUSG00000095742                         1
# ENSMUSG00000095041                        11
#
# [12052 rows x 19 columns]

# %%
adata_solo
# Out:
# AnnData object with n_obs × n_vars = 74491 × 12052
#     obs: '_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'is_doublet', 'is_outlier', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_mito', 'is_outlier_top_20', 'leiden', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'log1p_total_counts_ribo', 'n_counts', 'n_genes', 'n_genes_by_counts', 'origin', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'sample_id', 'total_counts', 'total_counts_mt', 'total_counts_ribo', 'value', 'condition'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
# Subsetting AnnData object
desired_cell_type = "10mix1"
subset_mask = adata_solo.obs["sample_id"] == desired_cell_type
subset_adata = adata_solo[subset_mask, :]

# %%
subset_adata
# Out:
# View of AnnData object with n_obs × n_vars = 3200 × 12052
#     obs: '_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'is_doublet', 'is_outlier', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_mito', 'is_outlier_top_20', 'leiden', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'log1p_total_counts_ribo', 'n_counts', 'n_genes', 'n_genes_by_counts', 'origin', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'sample_id', 'total_counts', 'total_counts_mt', 'total_counts_ribo', 'value', 'condition'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
list_var_names = adata_solo.raw.var_names.drop_duplicates()

# %%
adata_solo.raw.index= list_var_names

# %%
adata_colon.raw.index= adata_colon.raw.var_names.drop_duplicates()

# %%
adata_solo.raw = None

#del adata.raw

# %%
adata_solo.var.index = adata_solo.var.ensembl_id

# %%
adata_solo
# Out:
# AnnData object with n_obs × n_vars = 74491 × 12052
#     obs: '_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'is_doublet', 'is_outlier', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_mito', 'is_outlier_top_20', 'leiden', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'log1p_total_counts_ribo', 'n_counts', 'n_genes', 'n_genes_by_counts', 'origin', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'sample_id', 'total_counts', 'total_counts_mt', 'total_counts_ribo', 'value', 'condition'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap', 'batch_id_colors'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
annotation_dict = {'0': 'Tex',
 '1': 'Tn',
 '2': 'Tisg',
 '3': 'Tsen',
 '4': 'Tstr',
 '5': 'Trm',
 '6': 'Tstr'}

# %%
# Add cell type column based on annotation
adata_solo.obs['cell_type'] = [annotation_dict[clust] for clust in adata_solo.obs['leiden']]

# %%
adata_solo.obs.cell_type
# Out:
# AAACCTGAGTTAAGTG-0      Tn
# AAACCTGCAGGATCGA-0     Tex
# AAACCTGCATAACCTG-0    Tstr
# AAACCTGCATACCATG-0     Tex
# AAACCTGGTGTGCCTG-0      Tn
#                       ...
# TTTGTCATCCCTTGCA-7     Tex
# TTTGTCATCGTTGCCT-7     Tex
# TTTGTCATCTAACTGG-7    Tisg
# TTTGTCATCTCTGTCG-7     Tex
# TTTGTCATCTGTTGAG-7     Tex
# Name: cell_type, Length: 74491, dtype: object

# %%
genes_in_adata
# Out:
# ['Cxcr4',
#  'Xcl1',
#  'Cxcl10',
#  'Cxcr5',
#  'Ccr4',
#  'Cxcr6',
#  'Ccr5',
#  'Ccl5',
#  'Ccl3',
#  'Ccl4',
#  'Ccr7',
#  'Cxcr3']

# %%
import scanpy as sc

#genes_in_adata
genes_in_data_list  =  ["ENSMUSG00000045382","ENSMUSG00000026573","ENSMUSG00000034855","ENSMUSG00000047880","ENSMUSG00000047898","ENSMUSG00000048521","ENSMUSG00000079227","ENSMUSG00000035042","ENSMUSG00000000982","ENSMUSG00000018930","ENSMUSG00000037944","ENSMUSG00000050232"]
sc.pl.heatmap(adata_solo, genes_in_adata,gene_symbols="gene_name", groupby='cell_type', swap_axes=True)

# %%
import scanpy as sc

#genes_in_adata
genes_in_data_list  =  ["ENSMUSG00000045382","ENSMUSG00000026573","ENSMUSG00000034855","ENSMUSG00000047880","ENSMUSG00000047898","ENSMUSG00000048521","ENSMUSG00000079227","ENSMUSG00000035042","ENSMUSG00000000982","ENSMUSG00000018930","ENSMUSG00000037944","ENSMUSG00000050232"]
sc.pl.heatmap(adata_solo, genes_in_adata,gene_symbols="gene_name", groupby='origin', swap_axes=True)

# %%
import scanpy as sc

#genes_in_adata
genes_in_data_list  =  ["ENSMUSG00000045382","ENSMUSG00000026573","ENSMUSG00000034855","ENSMUSG00000047880","ENSMUSG00000047898","ENSMUSG00000048521","ENSMUSG00000079227","ENSMUSG00000035042","ENSMUSG00000000982","ENSMUSG00000018930","ENSMUSG00000037944","ENSMUSG00000050232"]
sc.pl.heatmap(adata_solo, genes_in_adata,gene_symbols="gene_name", groupby='condition', swap_axes=True)

# %%
import scanpy as sc

#genes_in_adata
genes_in_data_list  =  ["ENSMUSG00000045382","ENSMUSG00000026573","ENSMUSG00000034855","ENSMUSG00000047880","ENSMUSG00000047898","ENSMUSG00000048521","ENSMUSG00000079227","ENSMUSG00000035042","ENSMUSG00000000982","ENSMUSG00000018930","ENSMUSG00000037944","ENSMUSG00000050232"]
sc.pl.heatmap(adata_solo, genes_in_adata,gene_symbols="gene_name", groupby='sample_id', swap_axes=True)

# %%
sc.pl.dotplot(adata_solo,  genes_in_adata,gene_symbols="gene_name", groupby='cell_type', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  genes_in_adata,gene_symbols="gene_name", groupby='sample_id',  dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  genes_in_adata,gene_symbols="gene_name", groupby='origin',  dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  genes_in_adata,gene_symbols="gene_name", groupby='condition',  dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.matrixplot(adata_solo,  genes_in_adata,gene_symbols="gene_name", groupby='cell_type', dendrogram=False, swap_axes = True)

# %%
sc.pl.matrixplot(adata_solo,  genes_in_adata,gene_symbols="gene_name", groupby='sample_id',dendrogram=False, swap_axes = True)

# %%
sc.pl.matrixplot(adata_solo,  genes_in_adata,gene_symbols="gene_name", groupby='origin', dendrogram=False, swap_axes = True)

# %%
sc.pl.matrixplot(adata_solo,  genes_in_adata,gene_symbols="gene_name", groupby='condition', dendrogram=False, swap_axes = True)

# %%
gene_name =
gene_index = adata_solo.var.index.get_loc(gene_name)

# Get the corresponding value in the 'enseml_id' column
enseml_id = adata_solo.var.loc[gene_name, 'ensembl_id']

# %%
adata_solo.var.to_csv("adata_solo_var.csv")

# %%
filtered_denoised = sc.read_h5ad("/data/projects/2021/MicrobialMetabolites/single-cell-sorted-cd8/results/filtered/colon_and_tumor_adata_final_filtered.h5ad")
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
filtered_denoised.var
# Out:
#                         ensembl_id    feature_types       gene_name     mt  \
# gene_name
# Mrpl15          ENSMUSG00000033845  Gene Expression          Mrpl15  False
# Lypla1          ENSMUSG00000025903  Gene Expression          Lypla1  False
# Tcea1           ENSMUSG00000033813  Gene Expression           Tcea1  False
# Atp6v1h         ENSMUSG00000033793  Gene Expression         Atp6v1h  False
# Rb1cc1          ENSMUSG00000025907  Gene Expression          Rb1cc1  False
# ...                            ...              ...             ...    ...
# CAAA01118383.1  ENSMUSG00000063897  Gene Expression  CAAA01118383.1  False
# Vamp7           ENSMUSG00000051412  Gene Expression           Vamp7  False
# Tmlhe           ENSMUSG00000079834  Gene Expression           Tmlhe  False
# CAAA01147332.1  ENSMUSG00000095742  Gene Expression  CAAA01147332.1  False
# AC149090.1      ENSMUSG00000095041  Gene Expression      AC149090.1  False
#
#                  ribo  n_cells_by_counts  mean_counts  log1p_mean_counts  \
# gene_name
# Mrpl15          False              21544     0.265735           0.235653
# Lypla1          False              19780     0.223208           0.201477
# Tcea1           False              40520     0.502943           0.407425
# Atp6v1h         False              14525     0.160082           0.148491
# Rb1cc1          False              21173     0.236022           0.211898
# ...               ...                ...          ...                ...
# CAAA01118383.1  False               9796     0.108013           0.102569
# Vamp7           False               6678     0.073766           0.071172
# Tmlhe           False                593     0.006577           0.006556
# CAAA01147332.1  False              20856     0.302091           0.263971
# AC149090.1      False              29796     0.361714           0.308744
#
#                 pct_dropout_by_counts  total_counts  log1p_total_counts  \
# gene_name
# Mrpl15                      76.343992       24201.0           10.094191
# Lypla1                      78.280921       20328.0            9.919804
# Tcea1                       55.507730       45804.0           10.732148
# Atp6v1h                     84.051080       14579.0            9.587406
# Rb1cc1                      76.751362       21495.0            9.975622
# ...                               ...           ...                 ...
# CAAA01118383.1              89.243675        9837.0            9.194008
# Vamp7                       92.667340        6718.0            8.812695
# Tmlhe                       99.348867         599.0            6.396930
# CAAA01147332.1              77.099438       27512.0           10.222414
# AC149090.1                  67.283029       32942.0           10.402534
#
#                 n_cells  n_counts
# gene_name
# Mrpl15            21484   24002.0
# Lypla1            19725   20230.0
# Tcea1             40436   45545.0
# Atp6v1h           14481   14530.0
# Rb1cc1            21130   21450.0
# ...                 ...       ...
# CAAA01118383.1     9764    9803.0
# Vamp7              6640    6672.0
# Tmlhe               592     598.0
# CAAA01147332.1    20802   27325.0
# AC149090.1        29748   32886.0
#
# [12052 rows x 13 columns]

# %%
if "Cxcl2" in filtered_denoised.var.gene_name:
    print("T")

# %%
####TAKESHI

# %%
sur_prot = ["Cd69","Cd44","Cd8a","Cd8b1"]

# %%
sc.pl.dotplot(adata_solo,  sur_prot,gene_symbols="gene_name", groupby='cell_type',  dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  sur_prot,gene_symbols="gene_name", groupby='sample_id', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  sur_prot,gene_symbols="gene_name", groupby='condition', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  sur_prot,gene_symbols="gene_name", groupby='origin', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
genes_heatmap = ["Klrk1", "Ccl4", "Klrc1", "Gzma", "Dapk2", "Gzmk", "Gpr55","Ifng","Mcm5","Ifit3","Ramp3", "Gzmb",]

# %%
import scanpy as sc

sc.pl.heatmap(adata_solo, genes_heatmap,gene_symbols="gene_name", groupby='cell_type', swap_axes=True)

# %%
import scanpy as sc

sc.pl.heatmap(adata_solo, genes_heatmap,gene_symbols="gene_name", groupby='origin', swap_axes=True)

# %%
import scanpy as sc

sc.pl.heatmap(adata_solo, genes_heatmap,gene_symbols="gene_name", groupby='condition', swap_axes=True)

# %%
import scanpy as sc

sc.pl.heatmap(adata_solo, genes_heatmap,gene_symbols="gene_name", groupby='sample_id', swap_axes=True)

# %%
adata_solo.var.index = adata_solo.var.ensembl_id

# %%
sc.pl.dotplot(adata_solo,  genes_heatmap,gene_symbols="gene_name", groupby='cell_type',  dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  genes_heatmap,gene_symbols="gene_name", groupby='sample_id', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  genes_heatmap,gene_symbols="gene_name", groupby='origin', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  genes_heatmap,gene_symbols="gene_name", groupby='condition', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
genes_heatmap_cytokine = ["Csf1", "Il10ra","Il16", "Il18rap","Il21r","Il2rb","Il2rg","Il9r","Adam10","Adam8","Cd70"]

# %%
genes_heatmap_cytotoxicty = ["Ifng", "Tnf","Cxcl9"]

# %%
adata_solo
# Out:
# AnnData object with n_obs × n_vars = 74491 × 12052
#     obs: '_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'is_doublet', 'is_outlier', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_mito', 'is_outlier_top_20', 'leiden', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'log1p_total_counts_ribo', 'n_counts', 'n_genes', 'n_genes_by_counts', 'origin', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'sample_id', 'total_counts', 'total_counts_mt', 'total_counts_ribo', 'value', 'condition', 'cell_type'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap', 'batch_id_colors', 'leiden_colors', 'cell_type_colors', 'dendrogram_cell_type', 'dendrogram_sample_id', 'origin_colors', 'condition_colors', 'dendrogram_condition'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
sc.pl.dotplot(adata_solo, genes_heatmap_cytokine,gene_symbols="gene_name", groupby='sample_id',layer= "logcounts", dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  genes_heatmap_cytokine,gene_symbols="gene_name", groupby='cell_type', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  genes_heatmap_cytokine,gene_symbols="gene_name", groupby='origin', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pl.dotplot(adata_solo,  genes_heatmap_cytokine,gene_symbols="gene_name", groupby='condition', dendrogram=False, swap_axes = True)
# Out:
# /home/kvalem/.conda/envs/2022-default-scanpy/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
import pandas as pd

# Assuming you have a list of sample IDs and a corresponding list of cell counts
sample_ids = ["10mix", "11mix", "GF"]  # Replace with your actual sample IDs
number_of_cells = [826, 1111, 175]  # Replace with your actual cell count data

# Create a dictionary to store the data
data = {
    "sample_id": sample_ids,
    "number_of_cells": number_of_cells
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

print(df)
# Out:
#   sample_id  number_of_cells
# 0     10mix              826
# 1     11mix             1111
# 2        GF              175

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with sample IDs and cell counts

# Create a horizontal bar plot using matplotlib
plt.figure(figsize=(5, 3))  # Set the figure size

# Plot the data as horizontal bars
plt.barh(df['sample_id'], df['number_of_cells'],  fill=False)

# Customize the plot
plt.xlabel('Number of Cells')
plt.ylabel('Sample')
plt.title('')
plt.tight_layout()  # Adjust layout for better spacing

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming cell_type_df is your DataFrame with cell type counts

# Create a bar plot using matplotlib
plt.figure(figsize=(3, 5))  # Set the figure size

# Plot the data
plt.bar(df['sample_id'], df['number_of_cells'], fill=False)

# Customize the plot
plt.xlabel('Sample')
plt.ylabel('N. of cells')
plt.title('Sample Counts')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility


# Show the plot
plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[296], line 17
#      15 plt.title('Sample Counts')
#      16 plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
# ---> 17 plt.invert_yaxis()
#      18 # Show the plot
#      19 plt.tight_layout()  # Adjust layout for better spacing
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'invert_yaxis'
