# %%
import scvi

# %%
#import scanpy_helpers as sh

# %%
# Python packages
#import scanpy as sc

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import  decoupler as dc

# %%
path = "/data/projects/2021/MicrobialMetabolites/single-cell-sorted-cd8/results/solo"

# %%
adata_solo = scvi.data.read_h5ad(f"{path}/adata_nodoublet.h5ad")
# Out:
# /home/kvalem/.conda/envs/single_cell_sorted_scvi_2023_002/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
def update_columns(row):
   
    if "ICI" not in row['sample_id']:
        row['origin'] = "colon"
    else:
         row['origin'] = "til"
        
    return row

# Apply the function to each row in the DataFrame
adata_solo.obs = adata_solo.obs.apply(update_columns, axis=1)

# %%
def update_columns(row):
   
    if "ICI1"  in row['sample_id']:
        row['batch_id'] = "ICI1"
    elif "ICI2" in row['sample_id']:
         row['batch_id'] = "ICI2"
    elif row['sample_id'] == "10mix1":
        row['batch_id'] = "1"
    elif row['sample_id'] == "10mix2":
         row['batch_id'] = "2"
        
        
    return row

# Apply the function to each row in the DataFrame
adata_solo.obs = adata_solo.obs.apply(update_columns, axis=1)

# %%
def update_columns(row):
   
    if row['sample_id'] == "10mix1":
        row['condition'] = "10mix"
    elif row['sample_id'] == "10mix2":
         row['condition'] = "10mix"
    elif row['sample_id'] == "11mix1":
         row['condition'] = "11mix"
    elif row['sample_id'] == "11mix2":
         row['condition'] = "11mix"
    elif row['sample_id'] == "GF1":
         row['condition'] = "GF"
    elif row['sample_id'] == "GF2":
         row['condition'] = "GF"
    elif row['sample_id'] == "GF-ICI2-plus":
         row['condition'] = "GF-plus"
    elif row['sample_id'] == "GF-ICI1-plus":
         row['condition'] = "GF-plus"
    elif row['sample_id'] == "GF-ICI2":
         row['condition'] = "GF"
    elif row['sample_id'] == "GF-ICI1":
         row['condition'] = "GF"
    elif row['sample_id'] == "10mix-ICI1":
         row['condition'] = "10mix"
    elif row['sample_id'] == "10mix-ICI2":
         row['condition'] = "10mix"
    elif row['sample_id'] == "11mix-ICI1":
         row['condition'] = "11mix"
    elif row['sample_id'] == "11mix-ICI2":
         row['condition'] = "11mix"
    
    
        
        
    return row

# Apply the function to each row in the DataFrame
adata_solo.obs = adata_solo.obs.apply(update_columns, axis=1)

# %%
adata_solo.obs[["batch_id","sample_id","origin","condition"]]
# Out:
#                    batch_id     sample_id origin condition
# AAACCTGAGTTAAGTG-0        1        10mix1  colon     10mix
# AAACCTGCAGGATCGA-0        1        10mix1  colon     10mix
# AAACCTGCATAACCTG-0        1        10mix1  colon     10mix
# AAACCTGCATACCATG-0        1        10mix1  colon     10mix
# AAACCTGGTGTGCCTG-0        1        10mix1  colon     10mix
# ...                     ...           ...    ...       ...
# TTTGTCATCCCTTGCA-7     ICI2  GF-ICI2-plus    til   GF-plus
# TTTGTCATCGTTGCCT-7     ICI2  GF-ICI2-plus    til   GF-plus
# TTTGTCATCTAACTGG-7     ICI2  GF-ICI2-plus    til   GF-plus
# TTTGTCATCTCTGTCG-7     ICI2  GF-ICI2-plus    til   GF-plus
# TTTGTCATCTGTTGAG-7     ICI2  GF-ICI2-plus    til   GF-plus
#
# [74491 rows x 4 columns]

# %%
adata_solo.obs.sample_id.value_counts()
# Out:
# sample_id
# 10mix-ICI1      9024
# 10mix-ICI2      8876
# GF-ICI2-plus    7767
# 11mix-ICI1      7761
# 11mix-ICI2      7466
# GF-ICI1         6664
# GF-ICI1-plus    6020
# GF-ICI2         4916
# 11mix2          4197
# 10mix1          3200
# 11mix1          3036
# GF1             2722
# 10mix2          2432
# GF2              410
# Name: count, dtype: int64

# %%
adata_solo.obs
# Out:
#                     _scvi_batch  _scvi_labels batch batch_id is_doublet  \
# AAACCTGAGTTAAGTG-0            0             0     0        1    singlet
# AAACCTGCAGGATCGA-0            0             0     0        1    singlet
# AAACCTGCATAACCTG-0            0             0     0        1    singlet
# AAACCTGCATACCATG-0            0             0     0        1    singlet
# AAACCTGGTGTGCCTG-0            0             0     0        1    singlet
# ...                         ...           ...   ...      ...        ...
# TTTGTCATCCCTTGCA-7            0             0     7     ICI2    singlet
# TTTGTCATCGTTGCCT-7            0             0     7     ICI2    singlet
# TTTGTCATCTAACTGG-7            0             0     7     ICI2    singlet
# TTTGTCATCTCTGTCG-7            0             0     7     ICI2    singlet
# TTTGTCATCTGTTGAG-7            0             0     7     ICI2    singlet
#
#                     is_outlier  is_outlier_counts  is_outlier_genes  \
# AAACCTGAGTTAAGTG-0       False              False             False
# AAACCTGCAGGATCGA-0       False              False             False
# AAACCTGCATAACCTG-0       False              False             False
# AAACCTGCATACCATG-0       False              False             False
# AAACCTGGTGTGCCTG-0       False              False             False
# ...                        ...                ...               ...
# TTTGTCATCCCTTGCA-7       False              False             False
# TTTGTCATCGTTGCCT-7       False              False             False
# TTTGTCATCTAACTGG-7       False              False             False
# TTTGTCATCTCTGTCG-7       False              False             False
# TTTGTCATCTGTTGAG-7       False              False             False
#
#                     is_outlier_mito  is_outlier_top_20  ... origin  \
# AAACCTGAGTTAAGTG-0            False              False  ...  colon
# AAACCTGCAGGATCGA-0            False              False  ...  colon
# AAACCTGCATAACCTG-0             True              False  ...  colon
# AAACCTGCATACCATG-0             True              False  ...  colon
# AAACCTGGTGTGCCTG-0            False              False  ...  colon
# ...                             ...                ...  ...    ...
# TTTGTCATCCCTTGCA-7            False              False  ...    til
# TTTGTCATCGTTGCCT-7            False              False  ...    til
# TTTGTCATCTAACTGG-7            False              False  ...    til
# TTTGTCATCTCTGTCG-7            False              False  ...    til
# TTTGTCATCTGTTGAG-7            False              False  ...    til
#
#                     pct_counts_in_top_20_genes  pct_counts_mt  \
# AAACCTGAGTTAAGTG-0                   19.712352       3.976311
# AAACCTGCAGGATCGA-0                   15.031789       2.815622
# AAACCTGCATAACCTG-0                   26.896552       4.890282
# AAACCTGCATACCATG-0                   17.351318       2.697731
# AAACCTGGTGTGCCTG-0                   22.461713       4.537720
# ...                                        ...            ...
# TTTGTCATCCCTTGCA-7                   15.994485       1.895898
# TTTGTCATCGTTGCCT-7                   15.971183       2.114521
# TTTGTCATCTAACTGG-7                   17.100079       0.709220
# TTTGTCATCTCTGTCG-7                   21.934689       1.540357
# TTTGTCATCTGTTGAG-7                   16.799037       0.914561
#
#                     pct_counts_ribo     sample_id  total_counts  \
# AAACCTGAGTTAAGTG-0        16.920475        10mix1        1182.0
# AAACCTGCAGGATCGA-0         7.220708        10mix1        2202.0
# AAACCTGCATAACCTG-0         3.072100        10mix1        1595.0
# AAACCTGCATACCATG-0         1.839362        10mix1        1631.0
# AAACCTGGTGTGCCTG-0        23.511061        10mix1        3526.0
# ...                             ...           ...           ...
# TTTGTCATCCCTTGCA-7        14.788005  GF-ICI2-plus        2901.0
# TTTGTCATCGTTGCCT-7        10.946856  GF-ICI2-plus       10688.0
# TTTGTCATCTAACTGG-7         5.752561  GF-ICI2-plus        1269.0
# TTTGTCATCTCTGTCG-7        15.896489  GF-ICI2-plus        1623.0
# TTTGTCATCTGTTGAG-7        15.932611  GF-ICI2-plus        4155.0
#
#                     total_counts_mt  total_counts_ribo value  condition
# AAACCTGAGTTAAGTG-0             47.0              200.0     0      10mix
# AAACCTGCAGGATCGA-0             62.0              159.0     0      10mix
# AAACCTGCATAACCTG-0             78.0               49.0     0      10mix
# AAACCTGCATACCATG-0             44.0               30.0     0      10mix
# AAACCTGGTGTGCCTG-0            160.0              829.0     0      10mix
# ...                             ...                ...   ...        ...
# TTTGTCATCCCTTGCA-7             55.0              429.0     0    GF-plus
# TTTGTCATCGTTGCCT-7            226.0             1170.0     0    GF-plus
# TTTGTCATCTAACTGG-7              9.0               73.0     0    GF-plus
# TTTGTCATCTCTGTCG-7             25.0              258.0     0    GF-plus
# TTTGTCATCTGTTGAG-7             38.0              662.0     0    GF-plus
#
# [74491 rows x 28 columns]

# %%
adata_solo
# Out:
# AnnData object with n_obs × n_vars = 74491 × 12052
#     obs: '_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'is_doublet', 'is_outlier', 'is_outlier_counts', 'is_outlier_genes', 'is_outlier_mito', 'is_outlier_top_20', 'leiden', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'log1p_total_counts_ribo', 'n_counts', 'n_genes', 'n_genes_by_counts', 'origin', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'sample_id', 'total_counts', 'total_counts_mt', 'total_counts_ribo', 'value', 'condition'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', 'is_doublet_colors', 'leiden', 'log1p', 'neighbors', 'neighbors_uncorrected', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_scAR', 'X_scVI', 'X_umap', 'X_umap_uncorrected'
#     layers: 'counts', 'denoised', 'logcounts'
#     obsp: 'connectivities', 'distances', 'neighbors_uncorrected_connectivities', 'neighbors_uncorrected_distances'

# %%
pdata = dc.get_pseudobulk(
    adata_solo,
    sample_col='sample_id',
    groups_col='leiden',
    layer='logcounts',
    mode='sum',
    min_cells=0,
    min_counts=0
)
pdata
# Out:
# /home/kvalem/.conda/envs/single_cell_sorted_scvi_2023_002/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 91 × 12052
#     obs: '_scvi_batch', '_scvi_labels', 'batch', 'batch_id', 'is_doublet', 'is_outlier', 'leiden', 'origin', 'sample_id', 'value', 'condition', 'psbulk_n_cells', 'psbulk_counts'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     layers: 'psbulk_props'

# %%
pdata.obs
# Out:
#                  _scvi_batch _scvi_labels batch batch_id is_doublet  \
# 10mix1_colon               0            0     0        1    singlet
# 10mix2_colon               0            0     1        2    singlet
# 11mix1_colon               0            0     2      NaN    singlet
# 11mix2_colon               0            0     3      NaN    singlet
# GF1_colon                  0            0     4      NaN    singlet
# GF2_colon                  0            0     5      NaN    singlet
# 10mix-ICI1_til             0            0     0     ICI1    singlet
# 10mix-ICI2_til             0            0     1     ICI2    singlet
# 11mix-ICI1_til             0            0     2     ICI1    singlet
# 11mix-ICI2_til             0            0     3     ICI2    singlet
# GF-ICI1_til                0            0     4     ICI1    singlet
# GF-ICI1-plus_til           0            0     6     ICI1    singlet
# GF-ICI2_til                0            0     5     ICI2    singlet
# GF-ICI2-plus_til           0            0     7     ICI2    singlet
#
#                  is_outlier origin     sample_id value condition  \
# 10mix1_colon          False  colon        10mix1     0     10mix
# 10mix2_colon          False  colon        10mix2     0     10mix
# 11mix1_colon          False  colon        11mix1     0     11mix
# 11mix2_colon          False  colon        11mix2     0     11mix
# GF1_colon             False  colon           GF1     0        GF
# GF2_colon             False  colon           GF2     0        GF
# 10mix-ICI1_til        False    til    10mix-ICI1     0     10mix
# 10mix-ICI2_til        False    til    10mix-ICI2     0     10mix
# 11mix-ICI1_til        False    til    11mix-ICI1     0     11mix
# 11mix-ICI2_til        False    til    11mix-ICI2     0     11mix
# GF-ICI1_til           False    til       GF-ICI1     0        GF
# GF-ICI1-plus_til      False    til  GF-ICI1-plus     0   GF-plus
# GF-ICI2_til           False    til       GF-ICI2     0        GF
# GF-ICI2-plus_til      False    til  GF-ICI2-plus     0   GF-plus
#
#                   psbulk_n_cells  psbulk_counts
# 10mix1_colon              3200.0     17963023.0
# 10mix2_colon              2432.0     13734347.0
# 11mix1_colon              3036.0     15758320.0
# 11mix2_colon              4197.0     22834333.0
# GF1_colon                 2722.0     11551561.0
# GF2_colon                  410.0      1785099.0
# 10mix-ICI1_til            9024.0     50445990.0
# 10mix-ICI2_til            8876.0     51407638.0
# 11mix-ICI1_til            7761.0     51207524.0
# 11mix-ICI2_til            7466.0     47812480.0
# GF-ICI1_til               6664.0     39317017.0
# GF-ICI1-plus_til          6020.0     40080190.0
# GF-ICI2_til               4916.0     33933315.0
# GF-ICI2-plus_til          7767.0     59549553.0

# %%
for col in pdata.obs.columns:
    if pdata.obs[col].dtype == 'object':
        pdata.obs[col] = pd.to_numeric(pdata.obs[col], errors='coerce')

# %%
pdata.write('pseudobulk.h5ad')

# %%
import scanpy as sc
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 import scanpy as sc
#
# File ~/.conda/envs/single_cell_sorted_scvi_2023_002/lib/python3.11/site-packages/scanpy/__init__.py:17
#      15 from . import tools as tl
#      16 from . import preprocessing as pp
# ---> 17 from . import plotting as pl
#      18 from . import datasets, logging, queries, external, get
#      20 from anndata import AnnData, concat
#
# File ~/.conda/envs/single_cell_sorted_scvi_2023_002/lib/python3.11/site-packages/scanpy/plotting/__init__.py:1
# ----> 1 from ._anndata import (
#       2     scatter,
#       3     violin,
#       4     ranking,
#       5     clustermap,
#       6     tracksplot,
#       7     dendrogram,
#       8     correlation_matrix,
#       9     heatmap,
#      10 )
#      11 from ._dotplot import DotPlot, dotplot
#      12 from ._matrixplot import MatrixPlot, matrixplot
#
# File ~/.conda/envs/single_cell_sorted_scvi_2023_002/lib/python3.11/site-packages/scanpy/plotting/_anndata.py:28
#      26 from .._utils import sanitize_anndata, _doc_params, _check_use_raw
#      27 from .._compat import Literal
# ---> 28 from . import _utils
#      29 from ._utils import scatter_base, scatter_group, setup_axes
#      30 from ._utils import ColorLike, _FontWeight, _FontSize
#
# File ~/.conda/envs/single_cell_sorted_scvi_2023_002/lib/python3.11/site-packages/scanpy/plotting/_utils.py:36
#      30 _FontWeight = Literal['light', 'normal', 'medium', 'semibold', 'bold', 'heavy', 'black']
#      31 _FontSize = Literal[
#      32     'xx-small', 'x-small', 'small', 'medium', 'large', 'x-large', 'xx-large'
#      33 ]
# ---> 36 class _AxesSubplot(Axes, axes.SubplotBase, ABC):
#      37     """Intersection between Axes and SubplotBase: Has methods of both"""
#      40 # -------------------------------------------------------------------------------
#      41 # Simple plotting functions
#      42 # -------------------------------------------------------------------------------
#
# TypeError: metaclass conflict: the metaclass of a derived class must be a (non-strict) subclass of the metaclasses of all its bases

# %%
sc.tl.rank_genes_groups(pdata, 'leiden', method='wilcoxon')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 sc.tl.rank_genes_groups(pdata, 'leiden', method='wilcoxon')
#
# NameError: name 'sc' is not defined

# %%
sc.tl.rank_genes_groups(pb, groupby="leiden", method="wilcoxon")

# %%
pb
# Out:
# AnnData object with n_obs × n_vars = 84 × 12052
#     obs: 'sample_id', 'leiden', 'n_obs'
#     var: 'ensembl_id', 'feature_types', 'gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'log1p', 'rank_genes_groups'

# %%
with plt.rc_context({"figure.figsize": (12, 4)}):
    sc.pl.rank_genes_groups(pb, n_genes=50, save = "rank_genes.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 with plt.rc_context({"figure.figsize": (12, 4)}):
# ----> 2     sc.pl.rank_genes_groups(pb, n_genes=50, save = "rank_genes.pdf")
#
# NameError: name 'pb' is not defined

# %%
gene_list_ranked = sc.get.rank_genes_groups_df(adata_m, group="4", key="dea_leiden_filtered", gene_symbols="gene_symbols").dropna().head(50)
display(gene_list_ranked[["gene_symbols", "pvals_adj"]])

# %%
pb.uns["rank_genes_groups"]["names"][6]
# Out:
# ('Snrnp25', 'Rgs10', 'S1pr4', 'Lbr', 'Myl6', 'Zdhhc18', 'Anp32e')

# %%
mapping = {'Tex':['Rhoc', 'Cox7a2l', 'Supt4a', 'Fus', 'Ldha', 'Tle5', 'Grwd1'],
 'Tn': ['Emd', 'Tmem108', 'Dusp2', 'Hspa5', 'Actg1', 'Cmip', 'Wdr4'],
 'Tisg':['Grb7', 'Ldlrap1', 'Cdc42ep3', 'Os9', 'Actb', 'Csnk1g2', 'Dkc1'],
 'Tsen':['Borcs8', 'Sell', 'Cxcr3', 'March6', 'Hnrnpa2b1', 'Prex1', 'Tomm5'],
 'Tstr':['Nudt18', 'Rps27rt', 'Gzma', 'Rev3l', 'Calm1', 'Foxo1', 'Polr1b'],
 'Trm':['Tstd3', 'Dapl1', 'Cotl1', 'Sptbn1', 'Fxyd5', 'Kansl1', 'Txnl4a'],
 'Tstr':['Snrnp25', 'Rgs10', 'S1pr4', 'Lbr', 'Myl6', 'Zdhhc18', 'Anp32e']}

# %%
#CXL10  - ENSG00000169245
# cxcl9 - ENSG00000138755
# cxcl1 -  ENSG00000163739
# cxcl2  -  ENSG00000081041 
#TNFalpha  -  ENSG00000118503 (not sure)
